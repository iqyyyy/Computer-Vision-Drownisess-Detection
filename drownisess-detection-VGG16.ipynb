# %%
# !pip install pillow
# !pip install opencv-python
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# !pip install tensorflow==2.10
# !pip install scikit-learn

# %% [markdown]
# **Ini merupakan project computer vision untuk deteksi kantuk pengemudi kendaraan yang menggunakan algoritma Convolutional Neural Network (CNN) dengan pengimplementasian Transfer Learning VGG 16 menggunakan library tensorflow**
#
# Dataset: https://www.kaggle.com/datasets/hazemfahmy/openned-closed-eyes/data
#
# by Hazem Fahmy
#
# **Tentang Dataset**
#
# Selamat datang di Dataset Deteksi Kantuk UnityEyes! Dataset komprehensif ini dirancang untuk membantu para peneliti dan pengembang dalam tugas penting deteksi kantuk, yang secara khusus berfokus pada identifikasi pengemudi yang mengantuk berdasarkan perilaku mata. Dataset ini dikumpulkan menggunakan UnityEyes, sebuah simulator sintetis mata yang canggih, untuk memastikan data berkualitas tinggi. Data tersebut diberi label menggunakan ambang batas keterbukaan = 20 (referensi: https://github.com/SNTSVV/HUDD-Toolset)
#
# Dataset Deteksi Mengantuk terdiri dari beragam koleksi rekaman gerakan mata dari subjek dengan demografi yang berbeda-beda, yang diambil dalam skenario mengemudi yang terkendali. Data tersebut mencakup urutan gambar mata, yang diberi label secara cermat untuk menunjukkan apakah mata terbuka atau tertutup, yang berfungsi sebagai kebenaran dasar untuk mendeteksi pengemudi yang mengantuk.

# %% [markdown]
# ## **Import Library**

# %%
import os
import random
import numpy as np
import pandas as pd
from PIL import  Image
import string

import matplotlib.pyplot as plt
import seaborn as sns
import cv2
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, GlobalAveragePooling2D, BatchNormalization, Activation, Dropout, Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.utils import to_categorical
from keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

print(tf.__version__)
# Out:
# 2.12.0

# %%
import warnings
# Abaikan semua warning
warnings.filterwarnings('ignore')

# %% [markdown]
# Beberapa fungsi library yang digunakan:
# - **os**: Untuk mengoperasikan sistem operasi.
# - **cv2**: OpenCV untuk tugas-tugas computer vision.
# - **PIL**: Library pencitraan Python untuk tugas-tugas pemrosesan gambar.
# - **numpy**: Untuk komputasi numerik dan matriks.
# - **matplotlib.pyplot**: Untuk visualisasi plot.
# - **seaborn**: Untuk visualisasi plot.
# - **sklearn**: Untuk preprocessing data dan evaluasi akurasi
# - **tensorflow**: Untuk membangun dan melatih model pembelajaran mesin.

# %% [markdown]
# ## **Load Data from Directory**

# %%
# directory yang mengandung Image
root_dir = './drownisess/TrainingSet/TrainingSet'

# Iterasi melalui setiap folder di direktori root
folder_image_count = {}

for data in os.listdir(root_dir):
    path_folder = os.path.join(root_dir, data)
    if os.path.isdir(path_folder):
        # Menghitung jumlah file gambar di dalam folder
        num_images = len([name for name in os.listdir(path_folder) if os.path.isfile(os.path.join(path_folder, name)) and name.lower().endswith(('.png', '.jpg', '.jpeg'))])
        folder_image_count[data] = num_images

# Extract nama folder dan jumlah gambar yang sesuai
folders = list(folder_image_count.keys())
img_counts = list(folder_image_count.values())

# Plot bar chart
plt.figure(figsize=(10, 6))
plt.bar(range(len(folders)), img_counts, color = 'brown', align='center', alpha=0.7)
plt.xticks(range(len(folders)), folders, rotation=45)
plt.xlabel('Training Set')
plt.title('Number of Images Closed and Opened')
plt.tight_layout()
plt.show()

# %% [markdown]
# Setelah melakukan exttact data dari direktori path yang telah ditentukan, di dapatkan data Training Set yang terdiri dari 2 data mata Terbuka dengan 824 gambar dan mata Mengantuk dengan 880 gambar. Pastikan folder dataset berada ditempat yang sama seperti folder .py atau jupyter anda.
#
# Contoh direktori yang benar:
#
# **Project**
#
# ----- **drownisess**
#
# ----- **drownisess-detection.ipynb**

# %% [markdown]
# ## **Preprocessing Data**

# %% [markdown]
# Setelah dilakukan extract data, akan dilakukan transform data. Dataset akan dikelompokan berdasarkan label masing-masing lalu dilakukan resize image untuk mengcompress gambar mnejadi ukuran 150x150 dengan 3 channel warna karena merupakan gambar RGB.

# %%
categories = ['Opened', 'Closed'] # Folder yang akan dimuat
image_size = (150, 150) # Untuk setting ukuran gambar

# Inisialisasi list untuk menyimpan data dan label
X = []
Y = []

# Memuat gambar dan label dari setiap folder
for label, category in enumerate(categories):
    folder_path = os.path.join(root_dir, category)
    for filename in os.listdir(folder_path):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            img_path = os.path.join(folder_path, filename)
            img = Image.open(img_path)
            img = img.resize(image_size)  # Mengubah ukuran gambar
            img_array = np.array(img)     # Mengonversi gambar menjadi array numpy
            X.append(img_array)
            Y.append(label)

# Mengonversi list X dan Y menjadi array numpy
X = np.array(X)
Y = np.array(Y)

# %% [markdown]
# Label mata terbuka **“Opened”: 0** dan Label mata mengantuk **“Closed”: 1**

# %%
print(f'Total gambar: {len(X)}')
print(f'Total label: {len(Y)}')
print('kode label:', np.unique(Y))
# Out:
# Total gambar: 1704
# Total label: 1704
# kode label: [0 1]

# %%
X[0]
# Out:
# array([[[98, 98, 98],
#         [98, 98, 98],
#         [98, 98, 98],
#         ...,
#         [98, 98, 98],
#         [98, 98, 98],
#         [98, 98, 98]],
#
#        [[98, 98, 98],
#         [98, 98, 98],
#         [98, 98, 98],
#         ...,
#         [98, 98, 98],
#         [98, 98, 98],
#         [98, 98, 98]],
#
#        [[98, 98, 98],
#         [98, 98, 98],
#         [98, 98, 98],
#         ...,
#         [98, 98, 98],
#         [98, 98, 98],
#         [98, 98, 98]],
#
#        ...,
#
#        [[98, 98, 98],
#         [98, 98, 98],
#         [98, 98, 98],
#         ...,
#         [98, 98, 98],
#         [98, 98, 98],
#         [98, 98, 98]],
#
#        [[98, 98, 98],
#         [98, 98, 98],
#         [98, 98, 98],
#         ...,
#         [98, 98, 98],
#         [98, 98, 98],
#         [98, 98, 98]],
#
#        [[98, 98, 98],
#         [98, 98, 98],
#         [98, 98, 98],
#         ...,
#         [98, 98, 98],
#         [98, 98, 98],
#         [98, 98, 98]]], dtype=uint8)

# %% [markdown]
# Melakukan load data yang telah di extract dan di transform untuk melihat 5 sampel masing-masing setiap label

# %%
# Memisahkan gambar berdasarkan label
X_opened = X[Y == 0]
X_closed = X[Y == 1]

# Mengambil 5 sampel acak dari masing-masing kategori
opened_samples = np.random.choice(len(X_opened), 5, replace=False)
closed_samples = np.random.choice(len(X_closed), 5, replace=False)

X_samples = np.concatenate((X_opened[opened_samples], X_closed[closed_samples]))
Y_samples = np.concatenate((np.zeros(5), np.ones(5)))

# Menampilkan 10 sampel gambar
plt.figure(figsize=(15, 5))
for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(X_samples[i])
    plt.title('Opened' if Y_samples[i] == 0 else 'Closed')
    plt.axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# Membagi data menjadi data training 90% dan data validation 10%

# %%
x_train, x_validation, y_train, y_validation = train_test_split(X, Y, test_size=0.1, random_state=79)

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (1533, 150, 150, 3)
# (1533,)

# %% [markdown]
# terdapat 1533 gambar untuk data training

# %%
print(x_validation.shape)
print(y_validation.shape)
# Out:
# (171, 150, 150, 3)
# (171,)

# %% [markdown]
# terdapat 171 gambar untuk data validation

# %%
# Mengonversi y_train dan y_validation menjadi kategorikal (one-hot encoded vectors.)
y_train = to_categorical(y_train, num_classes=2)
y_validation = to_categorical(y_validation, num_classes=2)

# %% [markdown]
# ## **Model 1 CNN + VGG16 [Trainable layer - Regularization Yes - Batch Size 32]**

# %% [markdown]
# Model pertama adalah model CNN dengan memakai model VGG16 dengan menambah 1 dropout 0.3 lalu menginisialisasi Checkpoint Callback untuk menyimpan model dengan validation akurasi terbaik, lalu parameter yang akan dibandingkan adalah model CNN yang disuntikan model transfer learning VGG16 dengan melakukan training layer VGG16, memakai regularization dan batch size = 32

# %%
# model = tf.keras.applications.VGG16(include_top=False, weights='imagenet')
# model.summary()

# %%
# # Load base model dengan VGG16
# base_model = tf.keras.applications.VGG16(
#     include_top=False,
#     weights='imagenet',
#     input_tensor=None,
#     input_shape = (150, 150, 3),
#     classes=2,
# )

# # Membuka 24 layer terakhir kecuali BatchNormalization
# base_model.trainable = True
# layer_count = len(base_model.layers)
# layer_count

# %%
# Define jumlah kelas
num_classes = 2

# %%
# Load base model dengan VGG16
base_model = tf.keras.applications.VGG16(
    include_top=False,
    weights='imagenet',
    input_tensor=None,
    input_shape = (150, 150, 3),
    classes=2,
)

# Membuka layer convolutional dan pooling tertentu untuk dilatih
conv_count, pool_count = 0, 0
for layer in reversed(base_model.layers):  # Iterasi dari belakang
    if isinstance(layer, tf.keras.layers.Conv2D) and conv_count < 5:
        layer.trainable = True
        conv_count += 1
    elif isinstance(layer, tf.keras.layers.MaxPooling2D) and pool_count < 3:
        layer.trainable = True
        pool_count += 1
    else:
        layer.trainable = False  # Freeze layer lainnya

# Membuat input layer
inputs = Input(shape=(150, 150, 3))

# Menyusun model_VGG16_1
x = base_model(inputs)
x = GlobalAveragePooling2D()(x)
x = Dense(
    1024, 
    activation='relu', 
    kernel_regularizer=regularizers.l2(0.01)  # Menambahkan weight regularization
)(x)
x = Dropout(0.3)(x)
outputs = Dense(num_classes, activation='softmax')(x)  # Output layer

# Membuat model_VGG16_1
model_VGG16_1 = Model(inputs, outputs)

# Compile model_VGG16_1
model_VGG16_1.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Membuat checkpoint callback
checkpointVGG16_1 = ModelCheckpoint(
    'best_model_VGG16_1.h5', monitor='val_accuracy', verbose=1, save_best_only=True
)

# Early stopping minimal 10 epochs
class CustomEarlyStopping(EarlyStopping):
    def __init__(self, min_epochs=10, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.min_epochs = min_epochs

    def on_epoch_end(self, epoch, logs=None):
        # Cegah stop sebelum min_epochs terpenuhi
        if epoch + 1 < self.min_epochs:
            return
        super().on_epoch_end(epoch, logs)

# Custom EarlyStopping
custom_early_stopping = CustomEarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    min_epochs=10
)

# Training model_VGG16_1 dengan batch size 32
batch_size = 32
historyVGG16_1 = model_VGG16_1.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=30,
    validation_data=(x_validation, y_validation),
    callbacks=[checkpointVGG16_1, custom_early_stopping],
    verbose=1
)
# Out:
# Epoch 1/30
# 48/48 [==============================] - ETA: 0s - loss: 6.7111 - accuracy: 0.8532
# Epoch 1: val_accuracy improved from -inf to 0.95906, saving model to best_model_VGG16_1.h5
# 48/48 [==============================] - 162s 3s/step - loss: 6.7111 - accuracy: 0.8532 - val_loss: 5.9147 - val_accuracy: 0.9591
# Epoch 2/30
# 48/48 [==============================] - ETA: 0s - loss: 5.5240 - accuracy: 0.9348
# Epoch 2: val_accuracy improved from 0.95906 to 0.96491, saving model to best_model_VGG16_1.h5
# 48/48 [==============================] - 157s 3s/step - loss: 5.5240 - accuracy: 0.9348 - val_loss: 4.9743 - val_accuracy: 0.9649
# Epoch 3/30
# 48/48 [==============================] - ETA: 0s - loss: 4.5976 - accuracy: 0.9524
# Epoch 3: val_accuracy did not improve from 0.96491
# 48/48 [==============================] - 157s 3s/step - loss: 4.5976 - accuracy: 0.9524 - val_loss: 4.2321 - val_accuracy: 0.9532
# Epoch 4/30
# 48/48 [==============================] - ETA: 0s - loss: 3.8442 - accuracy: 0.9550
# Epoch 4: val_accuracy improved from 0.96491 to 0.97076, saving model to best_model_VGG16_1.h5
# 48/48 [==============================] - 162s 3s/step - loss: 3.8442 - accuracy: 0.9550 - val_loss: 3.4677 - val_accuracy: 0.9708
# Epoch 5/30
# 48/48 [==============================] - ETA: 0s - loss: 3.2019 - accuracy: 0.9609
# Epoch 5: val_accuracy did not improve from 0.97076
# 48/48 [==============================] - 160s 3s/step - loss: 3.2019 - accuracy: 0.9609 - val_loss: 2.9610 - val_accuracy: 0.9532
# Epoch 6/30
# 48/48 [==============================] - ETA: 0s - loss: 2.6642 - accuracy: 0.9726
# Epoch 6: val_accuracy did not improve from 0.97076
# 48/48 [==============================] - 163s 3s/step - loss: 2.6642 - accuracy: 0.9726 - val_loss: 2.4570 - val_accuracy: 0.9708
# Epoch 7/30
# 48/48 [==============================] - ETA: 0s - loss: 2.2583 - accuracy: 0.9720
# Epoch 7: val_accuracy did not improve from 0.97076
# 48/48 [==============================] - 160s 3s/step - loss: 2.2583 - accuracy: 0.9720 - val_loss: 2.0750 - val_accuracy: 0.9708
# Epoch 8/30
# 48/48 [==============================] - ETA: 0s - loss: 1.8791 - accuracy: 0.9785
# Epoch 8: val_accuracy did not improve from 0.97076
# 48/48 [==============================] - 157s 3s/step - loss: 1.8791 - accuracy: 0.9785 - val_loss: 1.7708 - val_accuracy: 0.9591
# Epoch 9/30
# 48/48 [==============================] - ETA: 0s - loss: 1.5750 - accuracy: 0.9830
# Epoch 9: val_accuracy did not improve from 0.97076
# 48/48 [==============================] - 148s 3s/step - loss: 1.5750 - accuracy: 0.9830 - val_loss: 1.5156 - val_accuracy: 0.9708
# Epoch 10/30
# 48/48 [==============================] - ETA: 0s - loss: 1.3166 - accuracy: 0.9948
# Epoch 10: val_accuracy did not improve from 0.97076
# 48/48 [==============================] - 148s 3s/step - loss: 1.3166 - accuracy: 0.9948 - val_loss: 1.6750 - val_accuracy: 0.9649
# Epoch 11/30
# 48/48 [==============================] - ETA: 0s - loss: 1.1716 - accuracy: 0.9778
# Epoch 11: val_accuracy did not improve from 0.97076
# 48/48 [==============================] - 155s 3s/step - loss: 1.1716 - accuracy: 0.9778 - val_loss: 1.1388 - val_accuracy: 0.9532
# Epoch 12/30
# 48/48 [==============================] - ETA: 0s - loss: 0.9860 - accuracy: 0.9876
# Epoch 12: val_accuracy improved from 0.97076 to 0.97661, saving model to best_model_VGG16_1.h5
# 48/48 [==============================] - 158s 3s/step - loss: 0.9860 - accuracy: 0.9876 - val_loss: 0.9851 - val_accuracy: 0.9766
# Epoch 13/30
# 48/48 [==============================] - ETA: 0s - loss: 0.8535 - accuracy: 0.9902
# Epoch 13: val_accuracy did not improve from 0.97661
# 48/48 [==============================] - 157s 3s/step - loss: 0.8535 - accuracy: 0.9902 - val_loss: 0.9569 - val_accuracy: 0.9532
# Epoch 14/30
# 48/48 [==============================] - ETA: 0s - loss: 0.7326 - accuracy: 0.9941
# Epoch 14: val_accuracy did not improve from 0.97661
# 48/48 [==============================] - 156s 3s/step - loss: 0.7326 - accuracy: 0.9941 - val_loss: 0.8692 - val_accuracy: 0.9649
# Epoch 15/30
# 48/48 [==============================] - ETA: 0s - loss: 0.6624 - accuracy: 0.9870
# Epoch 15: val_accuracy did not improve from 0.97661
# 48/48 [==============================] - 153s 3s/step - loss: 0.6624 - accuracy: 0.9870 - val_loss: 0.7602 - val_accuracy: 0.9649
# Epoch 16/30
# 48/48 [==============================] - ETA: 0s - loss: 0.5598 - accuracy: 0.9980
# Epoch 16: val_accuracy did not improve from 0.97661
# 48/48 [==============================] - 148s 3s/step - loss: 0.5598 - accuracy: 0.9980 - val_loss: 0.7248 - val_accuracy: 0.9649
# Epoch 17/30
# 48/48 [==============================] - ETA: 0s - loss: 0.4921 - accuracy: 0.9993
# Epoch 17: val_accuracy did not improve from 0.97661
# 48/48 [==============================] - 148s 3s/step - loss: 0.4921 - accuracy: 0.9993 - val_loss: 0.8327 - val_accuracy: 0.9591
# Epoch 18/30
# 48/48 [==============================] - ETA: 0s - loss: 0.4508 - accuracy: 0.9954
# Epoch 18: val_accuracy did not improve from 0.97661
# 48/48 [==============================] - 155s 3s/step - loss: 0.4508 - accuracy: 0.9954 - val_loss: 0.5436 - val_accuracy: 0.9649
# Epoch 19/30
# 48/48 [==============================] - ETA: 0s - loss: 0.4075 - accuracy: 0.9948
# Epoch 19: val_accuracy did not improve from 0.97661
# 48/48 [==============================] - 157s 3s/step - loss: 0.4075 - accuracy: 0.9948 - val_loss: 0.6200 - val_accuracy: 0.9708
# Epoch 20/30
# 48/48 [==============================] - ETA: 0s - loss: 0.3704 - accuracy: 0.9974
# Epoch 20: val_accuracy did not improve from 0.97661
# 48/48 [==============================] - 156s 3s/step - loss: 0.3704 - accuracy: 0.9974 - val_loss: 0.5097 - val_accuracy: 0.9649
# Epoch 21/30
# 48/48 [==============================] - ETA: 0s - loss: 0.3331 - accuracy: 0.9993
# Epoch 21: val_accuracy did not improve from 0.97661
# 48/48 [==============================] - 156s 3s/step - loss: 0.3331 - accuracy: 0.9993 - val_loss: 0.5623 - val_accuracy: 0.9591
# Epoch 22/30
# 48/48 [==============================] - ETA: 0s - loss: 0.3120 - accuracy: 0.9961
# Epoch 22: val_accuracy did not improve from 0.97661
# 48/48 [==============================] - 151s 3s/step - loss: 0.3120 - accuracy: 0.9961 - val_loss: 0.5625 - val_accuracy: 0.9357
# Epoch 23/30
# 48/48 [==============================] - ETA: 0s - loss: 0.2868 - accuracy: 0.9948
# Epoch 23: val_accuracy did not improve from 0.97661
# 48/48 [==============================] - 152s 3s/step - loss: 0.2868 - accuracy: 0.9948 - val_loss: 0.4442 - val_accuracy: 0.9591
# Epoch 24/30
# 48/48 [==============================] - ETA: 0s - loss: 0.2641 - accuracy: 0.9987
# Epoch 24: val_accuracy did not improve from 0.97661
# 48/48 [==============================] - 157s 3s/step - loss: 0.2641 - accuracy: 0.9987 - val_loss: 0.3864 - val_accuracy: 0.9474
# Epoch 25/30
# 48/48 [==============================] - ETA: 0s - loss: 0.2684 - accuracy: 0.9896
# Epoch 25: val_accuracy did not improve from 0.97661
# 48/48 [==============================] - 157s 3s/step - loss: 0.2684 - accuracy: 0.9896 - val_loss: 0.3841 - val_accuracy: 0.9591
# Epoch 26/30
# 48/48 [==============================] - ETA: 0s - loss: 0.2299 - accuracy: 0.9941
# Epoch 26: val_accuracy did not improve from 0.97661
# 48/48 [==============================] - 157s 3s/step - loss: 0.2299 - accuracy: 0.9941 - val_loss: 0.3966 - val_accuracy: 0.9649
# Epoch 27/30
# 48/48 [==============================] - ETA: 0s - loss: 0.2106 - accuracy: 0.9954
# Epoch 27: val_accuracy did not improve from 0.97661
# 48/48 [==============================] - 157s 3s/step - loss: 0.2106 - accuracy: 0.9954 - val_loss: 0.3560 - val_accuracy: 0.9766
# Epoch 28/30
# 48/48 [==============================] - ETA: 0s - loss: 0.2080 - accuracy: 0.9941
# Epoch 28: val_accuracy did not improve from 0.97661
# 48/48 [==============================] - 157s 3s/step - loss: 0.2080 - accuracy: 0.9941 - val_loss: 0.3835 - val_accuracy: 0.9532
# Epoch 29/30
# 48/48 [==============================] - ETA: 0s - loss: 0.1987 - accuracy: 0.9922
# Epoch 29: val_accuracy did not improve from 0.97661
# 48/48 [==============================] - 157s 3s/step - loss: 0.1987 - accuracy: 0.9922 - val_loss: 0.4098 - val_accuracy: 0.9649
# Epoch 30/30
# 48/48 [==============================] - ETA: 0s - loss: 0.1639 - accuracy: 0.9987
# Epoch 30: val_accuracy did not improve from 0.97661
# 48/48 [==============================] - 157s 3s/step - loss: 0.1639 - accuracy: 0.9987 - val_loss: 0.4169 - val_accuracy: 0.9649

# %%
# Plot loss & akurasi
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

# Plot training & validation akurasi
ax1.plot(historyVGG16_1.history['accuracy'])
ax1.plot(historyVGG16_1.history['val_accuracy'])
ax1.set_title('Model Accuracy')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
ax2.plot(historyVGG16_1.history['loss'])
ax2.plot(historyVGG16_1.history['val_loss'])
ax2.set_title('Model Loss')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %%
# Evaluasi akurasi dan loss pada set validation
loss, accuracy = model_VGG16_1.evaluate(x_validation, y_validation)
print(f'validation accuracy: {accuracy*100:.3f}%')
print(f'validation loss: {loss:.4f}')

# Generate classification report
y_pred = model_VGG16_1.predict(x_validation)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_validation, axis=1)

# Membuat classification_report
class_report_VGG16_1 = classification_report(y_true, y_pred_classes, target_names=categories)
print('Classification Report Model CNN + VGG16 1:')
print(class_report_VGG16_1)
# Out:
# 6/6 [==============================] - 9s 2s/step - loss: 0.4169 - accuracy: 0.9649
# validation accuracy: 96.491%
# validation loss: 0.4169
# 6/6 [==============================] - 9s 1s/step
# Classification Report Model CNN + VGG16 1:
#               precision    recall  f1-score   support
#
#       Opened       0.99      0.94      0.96        87
#       Closed       0.94      0.99      0.97        84
#
#     accuracy                           0.96       171
#    macro avg       0.97      0.97      0.96       171
# weighted avg       0.97      0.96      0.96       171

# %%
# Plot confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred_classes)
print("Confusion Matrix:")
print(conf_matrix)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Greens', xticklabels=categories, yticklabels=categories)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Confusion Matrix:
# [[82  5]
#  [ 1 83]]

# %% [markdown]
# ### **Predict the New Data with Model VGG16 1**

# %%
# Load model_predict_1 .h5
model_predict_1 = tf.keras.models.load_model('best_model_VGG16_1.h5')

# directory yang mengandung Image test
test_dir = './drownisess/TestSet/TestSet'

categories = ['Opened', 'Closed']

X_samples = []
Y_samples = []

def preprocess_image(image_path):
    img = Image.open(image_path)
    img = img.resize((150, 150))  
    img_array = np.array(img)
    return img_array


for category in categories:
    folder_path = os.path.join(test_dir, category)
    image_files = os.listdir(folder_path)
    random.shuffle(image_files)
    selected_images = image_files[:5]

    for image_file in selected_images:
        image_path = os.path.join(folder_path, image_file)
        img_array = preprocess_image(image_path)
        X_samples.append(img_array)
        if category == 'Opened':
            Y_samples.append(0)
        else:
            Y_samples.append(1)

X_samples = np.array(X_samples)
Y_samples = np.array(Y_samples)

num_samples = 10
num_cols = 5
num_rows = num_samples // num_cols

plt.figure(figsize=(15, 5))
for i in range(num_samples):
    current_image = X_samples[i]
    actual_label = Y_samples[i]

    batch_prediction = model_predict_1.predict(np.expand_dims(current_image, axis=0))
    predicted_label = np.argmax(batch_prediction)

    disease_labels = ['Opened', 'Closed']

    predicted_class = disease_labels[predicted_label]

    actual_class = disease_labels[actual_label]

    plt.subplot(num_rows, num_cols, i + 1)
    plt.imshow(current_image)
    plt.axis('off')
    plt.title("Actual: {}\nPredicted: {}".format(actual_class, predicted_class), fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 271ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 79ms/step

# %% [markdown]
# ## **Model 2 CNN + VGG16 [No Trainable layer - Regularization Yes - Batch Size 32]**

# %% [markdown]
# Model kedua adalah model CNN dengan memakai model VGG16 dengan menambah 1 dropout 0.3 lalu menginisialisasi Checkpoint Callback untuk menyimpan model dengan validation akurasi terbaik, lalu parameter yang akan dibandingkan adalah model CNN yang disuntikan model transfer learning VGG16 tanpa melakukan training layer VGG16, memakai regularization dan batch size = 32

# %%
# Load base model dengan VGG16
base_model = tf.keras.applications.VGG16(
    include_top=False,
    weights='imagenet',
    input_tensor=None,
    input_shape = (150, 150, 3),
    classes=2,
)

# Freeze model transfer learning dengan trainable = False (dinonaktifkan tariningnya)
base_model.trainable = False

# Menyusun model_VGG16_2
inputs = Input(shape=(150, 150, 3))
x = base_model(inputs, training=False)
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation = 'relu', kernel_regularizer=regularizers.l2(0.01))(x)
x = Dropout(0.3)(x)
# Output layer dengan softmax activation untuk multi-class classification dengan jumlah neuron sama dengan jumlah kelas
outputs = Dense(num_classes, activation = 'softmax')(x)

# Membuat model_VGG16_2
model_VGG16_2 = Model(inputs, outputs)

# Compile model_VGG16_2
model_VGG16_2.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Membuat checkpoint callback
checkpointVGG16_2 = ModelCheckpoint(
    'best_model_VGG16_2.h5', monitor='val_accuracy', verbose=1, save_best_only=True
)

# Early stopping minimal 10 epochs
class CustomEarlyStopping(EarlyStopping):
    def __init__(self, min_epochs=10, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.min_epochs = min_epochs

    def on_epoch_end(self, epoch, logs=None):
        # Cegah stop sebelum min_epochs terpenuhi
        if epoch + 1 < self.min_epochs:
            return
        super().on_epoch_end(epoch, logs)

# Custom EarlyStopping
custom_early_stopping = CustomEarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    min_epochs=10
)

# Training model_VGG16_2 dengan batch size 32
batch_size = 32
historyVGG16_2 = model_VGG16_2.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=30,
    validation_data=(x_validation, y_validation),
    callbacks=[checkpointVGG16_2, custom_early_stopping],
    verbose=1
)
# Out:
# Epoch 1/30
# 48/48 [==============================] - ETA: 0s - loss: 7.5284 - accuracy: 0.8056
# Epoch 1: val_accuracy improved from -inf to 0.92398, saving model to best_model_VGG16_2.h5
# 48/48 [==============================] - 98s 2s/step - loss: 7.5284 - accuracy: 0.8056 - val_loss: 6.4897 - val_accuracy: 0.9240
# Epoch 2/30
# 48/48 [==============================] - ETA: 0s - loss: 6.4180 - accuracy: 0.8911
# Epoch 2: val_accuracy improved from 0.92398 to 0.94737, saving model to best_model_VGG16_2.h5
# 48/48 [==============================] - 86s 2s/step - loss: 6.4180 - accuracy: 0.8911 - val_loss: 5.7267 - val_accuracy: 0.9474
# Epoch 3/30
# 48/48 [==============================] - ETA: 0s - loss: 5.7867 - accuracy: 0.8904
# Epoch 3: val_accuracy did not improve from 0.94737
# 48/48 [==============================] - 87s 2s/step - loss: 5.7867 - accuracy: 0.8904 - val_loss: 5.1178 - val_accuracy: 0.9357
# Epoch 4/30
# 48/48 [==============================] - ETA: 0s - loss: 5.1451 - accuracy: 0.9008
# Epoch 4: val_accuracy did not improve from 0.94737
# 48/48 [==============================] - 88s 2s/step - loss: 5.1451 - accuracy: 0.9008 - val_loss: 4.6429 - val_accuracy: 0.9474
# Epoch 5/30
# 48/48 [==============================] - ETA: 0s - loss: 4.7152 - accuracy: 0.9061
# Epoch 5: val_accuracy did not improve from 0.94737
# 48/48 [==============================] - 87s 2s/step - loss: 4.7152 - accuracy: 0.9061 - val_loss: 4.3015 - val_accuracy: 0.9064
# Epoch 6/30
# 48/48 [==============================] - ETA: 0s - loss: 4.3496 - accuracy: 0.9074
# Epoch 6: val_accuracy did not improve from 0.94737
# 48/48 [==============================] - 88s 2s/step - loss: 4.3496 - accuracy: 0.9074 - val_loss: 3.9777 - val_accuracy: 0.9357
# Epoch 7/30
# 48/48 [==============================] - ETA: 0s - loss: 3.8990 - accuracy: 0.9211
# Epoch 7: val_accuracy did not improve from 0.94737
# 48/48 [==============================] - 89s 2s/step - loss: 3.8990 - accuracy: 0.9211 - val_loss: 3.5778 - val_accuracy: 0.9357
# Epoch 8/30
# 48/48 [==============================] - ETA: 0s - loss: 3.6499 - accuracy: 0.9211
# Epoch 8: val_accuracy did not improve from 0.94737
# 48/48 [==============================] - 86s 2s/step - loss: 3.6499 - accuracy: 0.9211 - val_loss: 3.3314 - val_accuracy: 0.9415
# Epoch 9/30
# 48/48 [==============================] - ETA: 0s - loss: 3.3818 - accuracy: 0.9269
# Epoch 9: val_accuracy did not improve from 0.94737
# 48/48 [==============================] - 85s 2s/step - loss: 3.3818 - accuracy: 0.9269 - val_loss: 3.1778 - val_accuracy: 0.9415
# Epoch 10/30
# 48/48 [==============================] - ETA: 0s - loss: 3.0938 - accuracy: 0.9419
# Epoch 10: val_accuracy improved from 0.94737 to 0.95322, saving model to best_model_VGG16_2.h5
# 48/48 [==============================] - 86s 2s/step - loss: 3.0938 - accuracy: 0.9419 - val_loss: 2.8870 - val_accuracy: 0.9532
# Epoch 11/30
# 48/48 [==============================] - ETA: 0s - loss: 2.9531 - accuracy: 0.9315
# Epoch 11: val_accuracy did not improve from 0.95322
# 48/48 [==============================] - 86s 2s/step - loss: 2.9531 - accuracy: 0.9315 - val_loss: 2.7378 - val_accuracy: 0.9532
# Epoch 12/30
# 48/48 [==============================] - ETA: 0s - loss: 2.8080 - accuracy: 0.9289
# Epoch 12: val_accuracy did not improve from 0.95322
# 48/48 [==============================] - 92s 2s/step - loss: 2.8080 - accuracy: 0.9289 - val_loss: 2.5678 - val_accuracy: 0.9532
# Epoch 13/30
# 48/48 [==============================] - ETA: 0s - loss: 2.6333 - accuracy: 0.9374
# Epoch 13: val_accuracy did not improve from 0.95322
# 48/48 [==============================] - 94s 2s/step - loss: 2.6333 - accuracy: 0.9374 - val_loss: 2.4554 - val_accuracy: 0.9532
# Epoch 14/30
# 48/48 [==============================] - ETA: 0s - loss: 2.4660 - accuracy: 0.9472
# Epoch 14: val_accuracy did not improve from 0.95322
# 48/48 [==============================] - 94s 2s/step - loss: 2.4660 - accuracy: 0.9472 - val_loss: 2.3150 - val_accuracy: 0.9474
# Epoch 15/30
# 48/48 [==============================] - ETA: 0s - loss: 2.4013 - accuracy: 0.9354
# Epoch 15: val_accuracy did not improve from 0.95322
# 48/48 [==============================] - 95s 2s/step - loss: 2.4013 - accuracy: 0.9354 - val_loss: 2.2171 - val_accuracy: 0.9532
# Epoch 16/30
# 48/48 [==============================] - ETA: 0s - loss: 2.2713 - accuracy: 0.9439
# Epoch 16: val_accuracy did not improve from 0.95322
# 48/48 [==============================] - 95s 2s/step - loss: 2.2713 - accuracy: 0.9439 - val_loss: 2.1287 - val_accuracy: 0.9474
# Epoch 17/30
# 48/48 [==============================] - ETA: 0s - loss: 2.1675 - accuracy: 0.9485
# Epoch 17: val_accuracy did not improve from 0.95322
# 48/48 [==============================] - 95s 2s/step - loss: 2.1675 - accuracy: 0.9485 - val_loss: 2.0654 - val_accuracy: 0.9532
# Epoch 18/30
# 48/48 [==============================] - ETA: 0s - loss: 2.0994 - accuracy: 0.9465
# Epoch 18: val_accuracy improved from 0.95322 to 0.95906, saving model to best_model_VGG16_2.h5
# 48/48 [==============================] - 95s 2s/step - loss: 2.0994 - accuracy: 0.9465 - val_loss: 2.0065 - val_accuracy: 0.9591
# Epoch 19/30
# 48/48 [==============================] - ETA: 0s - loss: 1.9628 - accuracy: 0.9556
# Epoch 19: val_accuracy did not improve from 0.95906
# 48/48 [==============================] - 89s 2s/step - loss: 1.9628 - accuracy: 0.9556 - val_loss: 1.9281 - val_accuracy: 0.9532
# Epoch 20/30
# 48/48 [==============================] - ETA: 0s - loss: 1.9376 - accuracy: 0.9426
# Epoch 20: val_accuracy did not improve from 0.95906
# 48/48 [==============================] - 86s 2s/step - loss: 1.9376 - accuracy: 0.9426 - val_loss: 1.8561 - val_accuracy: 0.9474
# Epoch 21/30
# 48/48 [==============================] - ETA: 0s - loss: 1.8436 - accuracy: 0.9478
# Epoch 21: val_accuracy did not improve from 0.95906
# 48/48 [==============================] - 89s 2s/step - loss: 1.8436 - accuracy: 0.9478 - val_loss: 1.7956 - val_accuracy: 0.9415
# Epoch 22/30
# 48/48 [==============================] - ETA: 0s - loss: 1.7643 - accuracy: 0.9622
# Epoch 22: val_accuracy did not improve from 0.95906
# 48/48 [==============================] - 87s 2s/step - loss: 1.7643 - accuracy: 0.9622 - val_loss: 1.7357 - val_accuracy: 0.9357
# Epoch 23/30
# 48/48 [==============================] - ETA: 0s - loss: 1.6888 - accuracy: 0.9654
# Epoch 23: val_accuracy did not improve from 0.95906
# 48/48 [==============================] - 86s 2s/step - loss: 1.6888 - accuracy: 0.9654 - val_loss: 1.6938 - val_accuracy: 0.9591
# Epoch 24/30
# 48/48 [==============================] - ETA: 0s - loss: 1.6503 - accuracy: 0.9654
# Epoch 24: val_accuracy did not improve from 0.95906
# 48/48 [==============================] - 87s 2s/step - loss: 1.6503 - accuracy: 0.9654 - val_loss: 1.6553 - val_accuracy: 0.9474
# Epoch 25/30
# 48/48 [==============================] - ETA: 0s - loss: 1.6163 - accuracy: 0.9576
# Epoch 25: val_accuracy did not improve from 0.95906
# 48/48 [==============================] - 86s 2s/step - loss: 1.6163 - accuracy: 0.9576 - val_loss: 1.5877 - val_accuracy: 0.9474
# Epoch 26/30
# 48/48 [==============================] - ETA: 0s - loss: 1.5565 - accuracy: 0.9635
# Epoch 26: val_accuracy did not improve from 0.95906
# 48/48 [==============================] - 86s 2s/step - loss: 1.5565 - accuracy: 0.9635 - val_loss: 1.5911 - val_accuracy: 0.9415
# Epoch 27/30
# 48/48 [==============================] - ETA: 0s - loss: 1.5102 - accuracy: 0.9628
# Epoch 27: val_accuracy did not improve from 0.95906
# 48/48 [==============================] - 86s 2s/step - loss: 1.5102 - accuracy: 0.9628 - val_loss: 1.4876 - val_accuracy: 0.9474
# Epoch 28/30
# 48/48 [==============================] - ETA: 0s - loss: 1.4654 - accuracy: 0.9635
# Epoch 28: val_accuracy did not improve from 0.95906
# 48/48 [==============================] - 86s 2s/step - loss: 1.4654 - accuracy: 0.9635 - val_loss: 1.4540 - val_accuracy: 0.9532
# Epoch 29/30
# 48/48 [==============================] - ETA: 0s - loss: 1.4312 - accuracy: 0.9609
# Epoch 29: val_accuracy did not improve from 0.95906
# 48/48 [==============================] - 87s 2s/step - loss: 1.4312 - accuracy: 0.9609 - val_loss: 1.4123 - val_accuracy: 0.9474
# Epoch 30/30
# 48/48 [==============================] - ETA: 0s - loss: 1.3861 - accuracy: 0.9693
# Epoch 30: val_accuracy did not improve from 0.95906
# 48/48 [==============================] - 86s 2s/step - loss: 1.3861 - accuracy: 0.9693 - val_loss: 1.4205 - val_accuracy: 0.9415

# %%
# Plot loss & akurasi
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

# Plot training & validation akurasi
ax1.plot(historyVGG16_2.history['accuracy'])
ax1.plot(historyVGG16_2.history['val_accuracy'])
ax1.set_title('Model Accuracy')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
ax2.plot(historyVGG16_2.history['loss'])
ax2.plot(historyVGG16_2.history['val_loss'])
ax2.set_title('Model Loss')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %%
# Evaluasi akurasi dan loss pada set validation
loss, accuracy = model_VGG16_2.evaluate(x_validation, y_validation)
print(f'validation accuracy: {accuracy*100:.3f}%')
print(f'validation loss: {loss:.4f}')

# Generate classification report
y_pred = model_VGG16_2.predict(x_validation)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_validation, axis=1)

# Membuat classification_report
class_report_VGG16_2 = classification_report(y_true, y_pred_classes, target_names=categories)
print('Classification Report Model CNN + VGG16 2:')
print(class_report_VGG16_2)
# Out:
# 6/6 [==============================] - 9s 1s/step - loss: 1.4205 - accuracy: 0.9415
# validation accuracy: 94.152%
# validation loss: 1.4205
# 6/6 [==============================] - 8s 1s/step
# Classification Report Model CNN + VGG16 2:
#               precision    recall  f1-score   support
#
#       Opened       0.98      0.91      0.94        87
#       Closed       0.91      0.98      0.94        84
#
#     accuracy                           0.94       171
#    macro avg       0.94      0.94      0.94       171
# weighted avg       0.94      0.94      0.94       171

# %%
# Plot confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred_classes)
print("Confusion Matrix:")
print(conf_matrix)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Greens', xticklabels=categories, yticklabels=categories)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Confusion Matrix:
# [[79  8]
#  [ 2 82]]

# %% [markdown]
# ### **Predict the New Data with Model VGG16 2**

# %%
# Load model_predict_2 .h5
model_predict_2 = tf.keras.models.load_model('best_model_VGG16_2.h5')

# directory yang mengandung Image test
test_dir = './drownisess/TestSet/TestSet'

categories = ['Opened', 'Closed']

X_samples = []
Y_samples = []

def preprocess_image(image_path):
    img = Image.open(image_path)
    img = img.resize((150, 150))  
    img_array = np.array(img)
    return img_array


for category in categories:
    folder_path = os.path.join(test_dir, category)
    image_files = os.listdir(folder_path)
    random.shuffle(image_files)
    selected_images = image_files[:5]

    for image_file in selected_images:
        image_path = os.path.join(folder_path, image_file)
        img_array = preprocess_image(image_path)
        X_samples.append(img_array)
        if category == 'Opened':
            Y_samples.append(0)
        else:
            Y_samples.append(1)

X_samples = np.array(X_samples)
Y_samples = np.array(Y_samples)

num_samples = 10
num_cols = 5
num_rows = num_samples // num_cols

plt.figure(figsize=(15, 5))
for i in range(num_samples):
    current_image = X_samples[i]
    actual_label = Y_samples[i]

    batch_prediction = model_predict_2.predict(np.expand_dims(current_image, axis=0))
    predicted_label = np.argmax(batch_prediction)

    disease_labels = ['Opened', 'Closed']

    predicted_class = disease_labels[predicted_label]

    actual_class = disease_labels[actual_label]

    plt.subplot(num_rows, num_cols, i + 1)
    plt.imshow(current_image)
    plt.axis('off')
    plt.title("Actual: {}\nPredicted: {}".format(actual_class, predicted_class), fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 221ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 79ms/step

# %% [markdown]
# ## **Model 3 CNN + VGG16 [Trainable layer - Regularization No - Batch Size 32]**

# %% [markdown]
# Model ketiga adalah model CNN dengan memakai model VGG16 dengan menambah 1 dropout 0.3 lalu menginisialisasi Checkpoint Callback untuk menyimpan model dengan validation akurasi terbaik, lalu parameter yang akan dibandingkan adalah model CNN yang disuntikan model transfer learning VGG16 dengan melakukan training layer VGG16, tanpa regularization dan batch size = 32

# %%
# Load base model dengan VGG16
base_model = tf.keras.applications.VGG16(
    include_top=False,
    weights='imagenet',
    input_tensor=None,
    input_shape = (150, 150, 3),
    classes=2,
)

# Membuka layer convolutional dan pooling tertentu untuk dilatih
conv_count, pool_count = 0, 0
for layer in reversed(base_model.layers):  # Iterasi dari belakang
    if isinstance(layer, tf.keras.layers.Conv2D) and conv_count < 5:
        layer.trainable = True
        conv_count += 1
    elif isinstance(layer, tf.keras.layers.MaxPooling2D) and pool_count < 3:
        layer.trainable = True
        pool_count += 1
    else:
        layer.trainable = False  # Freeze layer lainnya

# Membuat input layer
inputs = Input(shape=(150, 150, 3))

# Menyusun model_VGG16_3
x = base_model(inputs)
x = GlobalAveragePooling2D()(x)
x = Dense(
    1024, 
    activation='relu')(x)
x = Dropout(0.3)(x)
outputs = Dense(num_classes, activation='softmax')(x)  # Output layer

# Membuat model_VGG16_3
model_VGG16_3 = Model(inputs, outputs)

# Compile model_VGG16_3
model_VGG16_3.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Membuat checkpoint callback
checkpointVGG16_3 = ModelCheckpoint(
    'best_model_VGG16_3.h5', monitor='val_accuracy', verbose=1, save_best_only=True
)

# Early stopping minimal 10 epochs
class CustomEarlyStopping(EarlyStopping):
    def __init__(self, min_epochs=10, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.min_epochs = min_epochs

    def on_epoch_end(self, epoch, logs=None):
        # Cegah stop sebelum min_epochs terpenuhi
        if epoch + 1 < self.min_epochs:
            return
        super().on_epoch_end(epoch, logs)

# Custom EarlyStopping
custom_early_stopping = CustomEarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    min_epochs=10
)

# Training model_VGG16_3 dengan batch size 32
batch_size = 32
historyVGG16_3 = model_VGG16_3.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=30,
    validation_data=(x_validation, y_validation),
    callbacks=[checkpointVGG16_3, custom_early_stopping],
    verbose=1
)
# Out:
# Epoch 1/30
# 48/48 [==============================] - ETA: 0s - loss: 0.2806 - accuracy: 0.9119
# Epoch 1: val_accuracy improved from -inf to 0.96491, saving model to best_model_VGG16_3.h5
# 48/48 [==============================] - 170s 4s/step - loss: 0.2806 - accuracy: 0.9119 - val_loss: 0.1153 - val_accuracy: 0.9649
# Epoch 2/30
# 48/48 [==============================] - ETA: 0s - loss: 0.1359 - accuracy: 0.9530
# Epoch 2: val_accuracy did not improve from 0.96491
# 48/48 [==============================] - 150s 3s/step - loss: 0.1359 - accuracy: 0.9530 - val_loss: 0.1095 - val_accuracy: 0.9649
# Epoch 3/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0920 - accuracy: 0.9667
# Epoch 3: val_accuracy improved from 0.96491 to 0.98246, saving model to best_model_VGG16_3.h5
# 48/48 [==============================] - 153s 3s/step - loss: 0.0920 - accuracy: 0.9667 - val_loss: 0.1203 - val_accuracy: 0.9825
# Epoch 4/30
# 48/48 [==============================] - ETA: 0s - loss: 0.1146 - accuracy: 0.9654
# Epoch 4: val_accuracy did not improve from 0.98246
# 48/48 [==============================] - 164s 3s/step - loss: 0.1146 - accuracy: 0.9654 - val_loss: 0.1291 - val_accuracy: 0.9532
# Epoch 5/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0728 - accuracy: 0.9778
# Epoch 5: val_accuracy did not improve from 0.98246
# 48/48 [==============================] - 164s 3s/step - loss: 0.0728 - accuracy: 0.9778 - val_loss: 0.0848 - val_accuracy: 0.9532
# Epoch 6/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0468 - accuracy: 0.9830
# Epoch 6: val_accuracy did not improve from 0.98246
# 48/48 [==============================] - 164s 3s/step - loss: 0.0468 - accuracy: 0.9830 - val_loss: 0.1620 - val_accuracy: 0.9708
# Epoch 7/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0546 - accuracy: 0.9817
# Epoch 7: val_accuracy did not improve from 0.98246
# 48/48 [==============================] - 160s 3s/step - loss: 0.0546 - accuracy: 0.9817 - val_loss: 0.1105 - val_accuracy: 0.9708
# Epoch 8/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0661 - accuracy: 0.9798
# Epoch 8: val_accuracy did not improve from 0.98246
# 48/48 [==============================] - 150s 3s/step - loss: 0.0661 - accuracy: 0.9798 - val_loss: 0.1078 - val_accuracy: 0.9591
# Epoch 9/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 0.9948
# Epoch 9: val_accuracy did not improve from 0.98246
# 48/48 [==============================] - 151s 3s/step - loss: 0.0213 - accuracy: 0.9948 - val_loss: 0.1900 - val_accuracy: 0.9649
# Epoch 10/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0087 - accuracy: 0.9987
# Epoch 10: val_accuracy did not improve from 0.98246
# 48/48 [==============================] - 150s 3s/step - loss: 0.0087 - accuracy: 0.9987 - val_loss: 0.2702 - val_accuracy: 0.9591
# Epoch 11/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0444 - accuracy: 0.9811
# Epoch 11: val_accuracy did not improve from 0.98246
# 48/48 [==============================] - 151s 3s/step - loss: 0.0444 - accuracy: 0.9811 - val_loss: 0.1570 - val_accuracy: 0.9591
# Epoch 12/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0136 - accuracy: 0.9948
# Epoch 12: val_accuracy did not improve from 0.98246
# 48/48 [==============================] - 151s 3s/step - loss: 0.0136 - accuracy: 0.9948 - val_loss: 0.2300 - val_accuracy: 0.9708
# Epoch 13/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.9993
# Epoch 13: val_accuracy did not improve from 0.98246
# 48/48 [==============================] - 151s 3s/step - loss: 0.0025 - accuracy: 0.9993 - val_loss: 0.3848 - val_accuracy: 0.9708
# Epoch 14/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0296 - accuracy: 0.9883
# Epoch 14: val_accuracy did not improve from 0.98246
# 48/48 [==============================] - 151s 3s/step - loss: 0.0296 - accuracy: 0.9883 - val_loss: 0.2320 - val_accuracy: 0.9708
# Epoch 15/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0395 - accuracy: 0.9883
# Epoch 15: val_accuracy did not improve from 0.98246
# 48/48 [==============================] - 150s 3s/step - loss: 0.0395 - accuracy: 0.9883 - val_loss: 0.2076 - val_accuracy: 0.9591
# Epoch 16/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0435 - accuracy: 0.9824
# Epoch 16: val_accuracy did not improve from 0.98246
# 48/48 [==============================] - 150s 3s/step - loss: 0.0435 - accuracy: 0.9824 - val_loss: 0.1707 - val_accuracy: 0.9591
# Epoch 17/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0110 - accuracy: 0.9961
# Epoch 17: val_accuracy did not improve from 0.98246
# 48/48 [==============================] - 157s 3s/step - loss: 0.0110 - accuracy: 0.9961 - val_loss: 0.4040 - val_accuracy: 0.9591
# Epoch 18/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.9987
# Epoch 18: val_accuracy did not improve from 0.98246
# 48/48 [==============================] - 160s 3s/step - loss: 0.0031 - accuracy: 0.9987 - val_loss: 0.2757 - val_accuracy: 0.9649
# Epoch 19/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0531 - accuracy: 0.9811
# Epoch 19: val_accuracy did not improve from 0.98246
# 48/48 [==============================] - 160s 3s/step - loss: 0.0531 - accuracy: 0.9811 - val_loss: 0.1758 - val_accuracy: 0.9415
# Epoch 20/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0300 - accuracy: 0.9883
# Epoch 20: val_accuracy did not improve from 0.98246
# 48/48 [==============================] - 160s 3s/step - loss: 0.0300 - accuracy: 0.9883 - val_loss: 0.2276 - val_accuracy: 0.9591
# Epoch 21/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0132 - accuracy: 0.9967
# Epoch 21: val_accuracy did not improve from 0.98246
# 48/48 [==============================] - 157s 3s/step - loss: 0.0132 - accuracy: 0.9967 - val_loss: 0.1437 - val_accuracy: 0.9591
# Epoch 22/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0237 - accuracy: 0.9928
# Epoch 22: val_accuracy did not improve from 0.98246
# 48/48 [==============================] - 151s 3s/step - loss: 0.0237 - accuracy: 0.9928 - val_loss: 0.2303 - val_accuracy: 0.9766
# Epoch 23/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0335 - accuracy: 0.9870
# Epoch 23: val_accuracy did not improve from 0.98246
# 48/48 [==============================] - 152s 3s/step - loss: 0.0335 - accuracy: 0.9870 - val_loss: 0.1111 - val_accuracy: 0.9649
# Epoch 24/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0128 - accuracy: 0.9974
# Epoch 24: val_accuracy did not improve from 0.98246
# 48/48 [==============================] - 150s 3s/step - loss: 0.0128 - accuracy: 0.9974 - val_loss: 0.1811 - val_accuracy: 0.9649
# Epoch 25/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0035 - accuracy: 0.9993
# Epoch 25: val_accuracy did not improve from 0.98246
# 48/48 [==============================] - 151s 3s/step - loss: 0.0035 - accuracy: 0.9993 - val_loss: 0.4976 - val_accuracy: 0.9591
# Epoch 26/30
# 48/48 [==============================] - ETA: 0s - loss: 2.1426e-04 - accuracy: 1.0000
# Epoch 26: val_accuracy did not improve from 0.98246
# 48/48 [==============================] - 150s 3s/step - loss: 2.1426e-04 - accuracy: 1.0000 - val_loss: 0.5700 - val_accuracy: 0.9649
# Epoch 27/30
# 48/48 [==============================] - ETA: 0s - loss: 4.9116e-05 - accuracy: 1.0000
# Epoch 27: val_accuracy did not improve from 0.98246
# 48/48 [==============================] - 150s 3s/step - loss: 4.9116e-05 - accuracy: 1.0000 - val_loss: 0.5459 - val_accuracy: 0.9649
# Epoch 28/30
# 48/48 [==============================] - ETA: 0s - loss: 3.1999e-05 - accuracy: 1.0000
# Epoch 28: val_accuracy did not improve from 0.98246
# 48/48 [==============================] - 150s 3s/step - loss: 3.1999e-05 - accuracy: 1.0000 - val_loss: 0.5360 - val_accuracy: 0.9649
# Epoch 29/30
# 48/48 [==============================] - ETA: 0s - loss: 1.7954e-05 - accuracy: 1.0000
# Epoch 29: val_accuracy did not improve from 0.98246
# 48/48 [==============================] - 150s 3s/step - loss: 1.7954e-05 - accuracy: 1.0000 - val_loss: 0.5280 - val_accuracy: 0.9649
# Epoch 30/30
# 48/48 [==============================] - ETA: 0s - loss: 1.8360e-05 - accuracy: 1.0000
# Epoch 30: val_accuracy did not improve from 0.98246
# 48/48 [==============================] - 151s 3s/step - loss: 1.8360e-05 - accuracy: 1.0000 - val_loss: 0.5333 - val_accuracy: 0.9649

# %%
# Plot loss & akurasi
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

# Plot training & validation akurasi
ax1.plot(historyVGG16_3.history['accuracy'])
ax1.plot(historyVGG16_3.history['val_accuracy'])
ax1.set_title('Model Accuracy')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
ax2.plot(historyVGG16_3.history['loss'])
ax2.plot(historyVGG16_3.history['val_loss'])
ax2.set_title('Model Loss')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %%
# Evaluasi akurasi dan loss pada set validation
loss, accuracy = model_VGG16_3.evaluate(x_validation, y_validation)
print(f'validation accuracy: {accuracy*100:.3f}%')
print(f'validation loss: {loss:.4f}')

# Generate classification report
y_pred = model_VGG16_3.predict(x_validation)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_validation, axis=1)

# Membuat classification_report
class_report_VGG16_3 = classification_report(y_true, y_pred_classes, target_names=categories)
print('Classification Report Model CNN + VGG16 3:')
print(class_report_VGG16_3)
# Out:
# 6/6 [==============================] - 8s 1s/step - loss: 0.5333 - accuracy: 0.9649
# validation accuracy: 96.491%
# validation loss: 0.5333
# 6/6 [==============================] - 9s 1s/step
# Classification Report Model CNN + VGG16 3:
#               precision    recall  f1-score   support
#
#       Opened       0.98      0.95      0.97        87
#       Closed       0.95      0.98      0.96        84
#
#     accuracy                           0.96       171
#    macro avg       0.96      0.97      0.96       171
# weighted avg       0.97      0.96      0.96       171

# %%
# Plot confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred_classes)
print("Confusion Matrix:")
print(conf_matrix)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Greens', xticklabels=categories, yticklabels=categories)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Confusion Matrix:
# [[83  4]
#  [ 2 82]]

# %% [markdown]
# ### **Predict the New Data with Model VGG16 3**

# %%
# Load model_predict_3 .h5
model_predict_3 = tf.keras.models.load_model('best_model_VGG16_3.h5')

# directory yang mengandung Image test
test_dir = './drownisess/TestSet/TestSet'

categories = ['Opened', 'Closed']

X_samples = []
Y_samples = []

def preprocess_image(image_path):
    img = Image.open(image_path)
    img = img.resize((150, 150))  
    img_array = np.array(img)
    return img_array


for category in categories:
    folder_path = os.path.join(test_dir, category)
    image_files = os.listdir(folder_path)
    random.shuffle(image_files)
    selected_images = image_files[:5]

    for image_file in selected_images:
        image_path = os.path.join(folder_path, image_file)
        img_array = preprocess_image(image_path)
        X_samples.append(img_array)
        if category == 'Opened':
            Y_samples.append(0)
        else:
            Y_samples.append(1)

X_samples = np.array(X_samples)
Y_samples = np.array(Y_samples)

num_samples = 10
num_cols = 5
num_rows = num_samples // num_cols

plt.figure(figsize=(15, 5))
for i in range(num_samples):
    current_image = X_samples[i]
    actual_label = Y_samples[i]

    batch_prediction = model_predict_3.predict(np.expand_dims(current_image, axis=0))
    predicted_label = np.argmax(batch_prediction)

    disease_labels = ['Opened', 'Closed']

    predicted_class = disease_labels[predicted_label]

    actual_class = disease_labels[actual_label]

    plt.subplot(num_rows, num_cols, i + 1)
    plt.imshow(current_image)
    plt.axis('off')
    plt.title("Actual: {}\nPredicted: {}".format(actual_class, predicted_class), fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 78ms/step

# %% [markdown]
# ## **Model 4 CNN + VGG16 [No Trainable layer - Regularization No - Batch Size 32]**

# %% [markdown]
# Model keempat adalah model CNN dengan memakai model VGG16 dengan menambah 1 dropout 0.3 lalu menginisialisasi Checkpoint Callback untuk menyimpan model dengan validation akurasi terbaik, lalu parameter yang akan dibandingkan adalah model CNN yang disuntikan model transfer learning VGG16 tanpa melakukan training layer VGG16, tanpa regularization dan batch size = 32

# %%
# Load base model dengan VGG16
base_model = tf.keras.applications.VGG16(
    include_top=False,
    weights='imagenet',
    input_tensor=None,
    input_shape = (150, 150, 3),
    classes=2,
)

# Freeze model transfer learning dengan trainable = False (dinonaktifkan tariningnya)
base_model.trainable = False

# Menyusun model_VGG16_4
inputs = Input(shape=(150, 150, 3))
x = base_model(inputs, training=False)
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation = 'relu')(x)
x = Dropout(0.3)(x)
# Output layer dengan softmax activation untuk multi-class classification dengan jumlah neuron sama dengan jumlah kelas
outputs = Dense(num_classes, activation = 'softmax')(x)

# Membuat model_VGG16_4
model_VGG16_4 = Model(inputs, outputs)

# Compile model_VGG16_4
model_VGG16_4.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Membuat checkpoint callback
checkpointVGG16_4 = ModelCheckpoint(
    'best_model_VGG16_4.h5', monitor='val_accuracy', verbose=1, save_best_only=True
)

# Early stopping minimal 10 epochs
class CustomEarlyStopping(EarlyStopping):
    def __init__(self, min_epochs=10, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.min_epochs = min_epochs

    def on_epoch_end(self, epoch, logs=None):
        # Cegah stop sebelum min_epochs terpenuhi
        if epoch + 1 < self.min_epochs:
            return
        super().on_epoch_end(epoch, logs)

# Custom EarlyStopping
custom_early_stopping = CustomEarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    min_epochs=10
)

# Training model_VGG16_4 dengan batch size 32
batch_size = 32
historyVGG16_4 = model_VGG16_4.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=30,
    validation_data=(x_validation, y_validation),
    callbacks=[checkpointVGG16_4, custom_early_stopping],
    verbose=1
)
# Out:
# Epoch 1/30
# 48/48 [==============================] - ETA: 0s - loss: 1.5969 - accuracy: 0.7228
# Epoch 1: val_accuracy improved from -inf to 0.91813, saving model to best_model_VGG16_4.h5
# 48/48 [==============================] - 95s 2s/step - loss: 1.5969 - accuracy: 0.7228 - val_loss: 0.4146 - val_accuracy: 0.9181
# Epoch 2/30
# 48/48 [==============================] - ETA: 0s - loss: 0.5871 - accuracy: 0.8813
# Epoch 2: val_accuracy improved from 0.91813 to 0.92398, saving model to best_model_VGG16_4.h5
# 48/48 [==============================] - 106s 2s/step - loss: 0.5871 - accuracy: 0.8813 - val_loss: 0.3512 - val_accuracy: 0.9240
# Epoch 3/30
# 48/48 [==============================] - ETA: 0s - loss: 0.4789 - accuracy: 0.9054
# Epoch 3: val_accuracy improved from 0.92398 to 0.92982, saving model to best_model_VGG16_4.h5
# 48/48 [==============================] - 95s 2s/step - loss: 0.4789 - accuracy: 0.9054 - val_loss: 0.2569 - val_accuracy: 0.9298
# Epoch 4/30
# 48/48 [==============================] - ETA: 0s - loss: 0.5314 - accuracy: 0.8989
# Epoch 4: val_accuracy did not improve from 0.92982
# 48/48 [==============================] - 95s 2s/step - loss: 0.5314 - accuracy: 0.8989 - val_loss: 0.2722 - val_accuracy: 0.9298
# Epoch 5/30
# 48/48 [==============================] - ETA: 0s - loss: 0.4345 - accuracy: 0.9152
# Epoch 5: val_accuracy improved from 0.92982 to 0.93567, saving model to best_model_VGG16_4.h5
# 48/48 [==============================] - 103s 2s/step - loss: 0.4345 - accuracy: 0.9152 - val_loss: 0.3282 - val_accuracy: 0.9357
# Epoch 6/30
# 48/48 [==============================] - ETA: 0s - loss: 0.4558 - accuracy: 0.9048
# Epoch 6: val_accuracy did not improve from 0.93567
# 48/48 [==============================] - 101s 2s/step - loss: 0.4558 - accuracy: 0.9048 - val_loss: 0.2546 - val_accuracy: 0.9298
# Epoch 7/30
# 48/48 [==============================] - ETA: 0s - loss: 0.3686 - accuracy: 0.9198
# Epoch 7: val_accuracy did not improve from 0.93567
# 48/48 [==============================] - 101s 2s/step - loss: 0.3686 - accuracy: 0.9198 - val_loss: 0.2416 - val_accuracy: 0.9357
# Epoch 8/30
# 48/48 [==============================] - ETA: 0s - loss: 0.3823 - accuracy: 0.9106
# Epoch 8: val_accuracy did not improve from 0.93567
# 48/48 [==============================] - 102s 2s/step - loss: 0.3823 - accuracy: 0.9106 - val_loss: 0.2222 - val_accuracy: 0.9357
# Epoch 9/30
# 48/48 [==============================] - ETA: 0s - loss: 0.3458 - accuracy: 0.9211
# Epoch 9: val_accuracy did not improve from 0.93567
# 48/48 [==============================] - 103s 2s/step - loss: 0.3458 - accuracy: 0.9211 - val_loss: 0.2149 - val_accuracy: 0.9357
# Epoch 10/30
# 48/48 [==============================] - ETA: 0s - loss: 0.2918 - accuracy: 0.9211
# Epoch 10: val_accuracy improved from 0.93567 to 0.94152, saving model to best_model_VGG16_4.h5
# 48/48 [==============================] - 97s 2s/step - loss: 0.2918 - accuracy: 0.9211 - val_loss: 0.2896 - val_accuracy: 0.9415
# Epoch 11/30
# 48/48 [==============================] - ETA: 0s - loss: 0.2342 - accuracy: 0.9419
# Epoch 11: val_accuracy did not improve from 0.94152
# 48/48 [==============================] - 97s 2s/step - loss: 0.2342 - accuracy: 0.9419 - val_loss: 0.2726 - val_accuracy: 0.9298
# Epoch 12/30
# 48/48 [==============================] - ETA: 0s - loss: 0.2373 - accuracy: 0.9348
# Epoch 12: val_accuracy did not improve from 0.94152
# 48/48 [==============================] - 104s 2s/step - loss: 0.2373 - accuracy: 0.9348 - val_loss: 0.2122 - val_accuracy: 0.9298
# Epoch 13/30
# 48/48 [==============================] - ETA: 0s - loss: 0.2329 - accuracy: 0.9393
# Epoch 13: val_accuracy improved from 0.94152 to 0.94737, saving model to best_model_VGG16_4.h5
# 48/48 [==============================] - 100s 2s/step - loss: 0.2329 - accuracy: 0.9393 - val_loss: 0.2130 - val_accuracy: 0.9474
# Epoch 14/30
# 48/48 [==============================] - ETA: 0s - loss: 0.2000 - accuracy: 0.9485
# Epoch 14: val_accuracy did not improve from 0.94737
# 48/48 [==============================] - 103s 2s/step - loss: 0.2000 - accuracy: 0.9485 - val_loss: 0.2336 - val_accuracy: 0.9415
# Epoch 15/30
# 48/48 [==============================] - ETA: 0s - loss: 0.1761 - accuracy: 0.9439
# Epoch 15: val_accuracy did not improve from 0.94737
# 48/48 [==============================] - 103s 2s/step - loss: 0.1761 - accuracy: 0.9439 - val_loss: 0.2188 - val_accuracy: 0.9357
# Epoch 16/30
# 48/48 [==============================] - ETA: 0s - loss: 0.1997 - accuracy: 0.9419
# Epoch 16: val_accuracy did not improve from 0.94737
# 48/48 [==============================] - 98s 2s/step - loss: 0.1997 - accuracy: 0.9419 - val_loss: 0.2258 - val_accuracy: 0.9474
# Epoch 17/30
# 48/48 [==============================] - ETA: 0s - loss: 0.1860 - accuracy: 0.9524
# Epoch 17: val_accuracy did not improve from 0.94737
# 48/48 [==============================] - 101s 2s/step - loss: 0.1860 - accuracy: 0.9524 - val_loss: 0.2138 - val_accuracy: 0.9415
# Epoch 18/30
# 48/48 [==============================] - ETA: 0s - loss: 0.1606 - accuracy: 0.9576
# Epoch 18: val_accuracy did not improve from 0.94737
# 48/48 [==============================] - 106s 2s/step - loss: 0.1606 - accuracy: 0.9576 - val_loss: 0.1877 - val_accuracy: 0.9415
# Epoch 19/30
# 48/48 [==============================] - ETA: 0s - loss: 0.1470 - accuracy: 0.9485
# Epoch 19: val_accuracy did not improve from 0.94737
# 48/48 [==============================] - 103s 2s/step - loss: 0.1470 - accuracy: 0.9485 - val_loss: 0.2177 - val_accuracy: 0.9474
# Epoch 20/30
# 48/48 [==============================] - ETA: 0s - loss: 0.1506 - accuracy: 0.9530
# Epoch 20: val_accuracy improved from 0.94737 to 0.95906, saving model to best_model_VGG16_4.h5
# 48/48 [==============================] - 103s 2s/step - loss: 0.1506 - accuracy: 0.9530 - val_loss: 0.2062 - val_accuracy: 0.9591
# Epoch 21/30
# 48/48 [==============================] - ETA: 0s - loss: 0.1416 - accuracy: 0.9537
# Epoch 21: val_accuracy did not improve from 0.95906
# 48/48 [==============================] - 100s 2s/step - loss: 0.1416 - accuracy: 0.9537 - val_loss: 0.1827 - val_accuracy: 0.9591
# Epoch 22/30
# 48/48 [==============================] - ETA: 0s - loss: 0.1084 - accuracy: 0.9687
# Epoch 22: val_accuracy did not improve from 0.95906
# 48/48 [==============================] - 97s 2s/step - loss: 0.1084 - accuracy: 0.9687 - val_loss: 0.1890 - val_accuracy: 0.9591
# Epoch 23/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0996 - accuracy: 0.9661
# Epoch 23: val_accuracy did not improve from 0.95906
# 48/48 [==============================] - 97s 2s/step - loss: 0.0996 - accuracy: 0.9661 - val_loss: 0.2078 - val_accuracy: 0.9591
# Epoch 24/30
# 48/48 [==============================] - ETA: 0s - loss: 0.1025 - accuracy: 0.9654
# Epoch 24: val_accuracy did not improve from 0.95906
# 48/48 [==============================] - 97s 2s/step - loss: 0.1025 - accuracy: 0.9654 - val_loss: 0.2105 - val_accuracy: 0.9591
# Epoch 25/30
# 48/48 [==============================] - ETA: 0s - loss: 0.1046 - accuracy: 0.9667
# Epoch 25: val_accuracy did not improve from 0.95906
# 48/48 [==============================] - 97s 2s/step - loss: 0.1046 - accuracy: 0.9667 - val_loss: 0.2571 - val_accuracy: 0.9532
# Epoch 26/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0894 - accuracy: 0.9654
# Epoch 26: val_accuracy did not improve from 0.95906
# 48/48 [==============================] - 98s 2s/step - loss: 0.0894 - accuracy: 0.9654 - val_loss: 0.2337 - val_accuracy: 0.9591
# Epoch 27/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0799 - accuracy: 0.9713
# Epoch 27: val_accuracy did not improve from 0.95906
# 48/48 [==============================] - 97s 2s/step - loss: 0.0799 - accuracy: 0.9713 - val_loss: 0.2166 - val_accuracy: 0.9591
# Epoch 28/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0736 - accuracy: 0.9733
# Epoch 28: val_accuracy did not improve from 0.95906
# 48/48 [==============================] - 89s 2s/step - loss: 0.0736 - accuracy: 0.9733 - val_loss: 0.2055 - val_accuracy: 0.9532
# Epoch 29/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0854 - accuracy: 0.9706
# Epoch 29: val_accuracy did not improve from 0.95906
# 48/48 [==============================] - 86s 2s/step - loss: 0.0854 - accuracy: 0.9706 - val_loss: 0.2123 - val_accuracy: 0.9415
# Epoch 30/30
# 48/48 [==============================] - ETA: 0s - loss: 0.0483 - accuracy: 0.9791
# Epoch 30: val_accuracy did not improve from 0.95906
# 48/48 [==============================] - 86s 2s/step - loss: 0.0483 - accuracy: 0.9791 - val_loss: 0.2328 - val_accuracy: 0.9415

# %%
# Plot loss & akurasi
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

# Plot training & validation akurasi
ax1.plot(historyVGG16_4.history['accuracy'])
ax1.plot(historyVGG16_4.history['val_accuracy'])
ax1.set_title('Model Accuracy')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
ax2.plot(historyVGG16_4.history['loss'])
ax2.plot(historyVGG16_4.history['val_loss'])
ax2.set_title('Model Loss')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %%
# Evaluasi akurasi dan loss pada set validation
loss, accuracy = model_VGG16_4.evaluate(x_validation, y_validation)
print(f'validation accuracy: {accuracy*100:.3f}%')
print(f'validation loss: {loss:.4f}')

# Generate classification report
y_pred = model_VGG16_4.predict(x_validation)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_validation, axis=1)

# Membuat classification_report
class_report_VGG16_4 = classification_report(y_true, y_pred_classes, target_names=categories)
print('Classification Report Model CNN + VGG16 4:')
print(class_report_VGG16_4)
# Out:
# 6/6 [==============================] - 8s 1s/step - loss: 0.2328 - accuracy: 0.9415
# validation accuracy: 94.152%
# validation loss: 0.2328
# 6/6 [==============================] - 9s 1s/step
# Classification Report Model CNN + VGG16 4:
#               precision    recall  f1-score   support
#
#       Opened       0.96      0.92      0.94        87
#       Closed       0.92      0.96      0.94        84
#
#     accuracy                           0.94       171
#    macro avg       0.94      0.94      0.94       171
# weighted avg       0.94      0.94      0.94       171

# %%
# Plot confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred_classes)
print("Confusion Matrix:")
print(conf_matrix)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Greens', xticklabels=categories, yticklabels=categories)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Confusion Matrix:
# [[80  7]
#  [ 3 81]]

# %% [markdown]
# ### **Predict the New Data with Model VGG16 4**

# %%
# Load model_predict_4 .h5
model_predict_4 = tf.keras.models.load_model('best_model_VGG16_4.h5')

# directory yang mengandung Image test
test_dir = './drownisess/TestSet/TestSet'

categories = ['Opened', 'Closed']

X_samples = []
Y_samples = []

def preprocess_image(image_path):
    img = Image.open(image_path)
    img = img.resize((150, 150))  
    img_array = np.array(img)
    return img_array


for category in categories:
    folder_path = os.path.join(test_dir, category)
    image_files = os.listdir(folder_path)
    random.shuffle(image_files)
    selected_images = image_files[:5]

    for image_file in selected_images:
        image_path = os.path.join(folder_path, image_file)
        img_array = preprocess_image(image_path)
        X_samples.append(img_array)
        if category == 'Opened':
            Y_samples.append(0)
        else:
            Y_samples.append(1)

X_samples = np.array(X_samples)
Y_samples = np.array(Y_samples)

num_samples = 10
num_cols = 5
num_rows = num_samples // num_cols

plt.figure(figsize=(15, 5))
for i in range(num_samples):
    current_image = X_samples[i]
    actual_label = Y_samples[i]

    batch_prediction = model_predict_4.predict(np.expand_dims(current_image, axis=0))
    predicted_label = np.argmax(batch_prediction)

    disease_labels = ['Opened', 'Closed']

    predicted_class = disease_labels[predicted_label]

    actual_class = disease_labels[actual_label]

    plt.subplot(num_rows, num_cols, i + 1)
    plt.imshow(current_image)
    plt.axis('off')
    plt.title("Actual: {}\nPredicted: {}".format(actual_class, predicted_class), fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 79ms/step

# %% [markdown]
# ## **Model 5 CNN + VGG16 [Trainable layer - Regularization Yes - Batch Size 64]**

# %% [markdown]
# Model kelima adalah model CNN dengan memakai model VGG16 dengan menambah 1 dropout 0.3 lalu menginisialisasi Checkpoint Callback untuk menyimpan model dengan validation akurasi terbaik, lalu parameter yang akan dibandingkan adalah model CNN yang disuntikan model transfer learning VGG16 dengan melakukan training layer VGG16, memakai regularization dan batch size = 64

# %%
# Load base model dengan VGG16
base_model = tf.keras.applications.VGG16(
    include_top=False,
    weights='imagenet',
    input_tensor=None,
    input_shape = (150, 150, 3),
    classes=2,
)

# Membuka layer convolutional dan pooling tertentu untuk dilatih
conv_count, pool_count = 0, 0
for layer in reversed(base_model.layers):  # Iterasi dari belakang
    if isinstance(layer, tf.keras.layers.Conv2D) and conv_count < 5:
        layer.trainable = True
        conv_count += 1
    elif isinstance(layer, tf.keras.layers.MaxPooling2D) and pool_count < 3:
        layer.trainable = True
        pool_count += 1
    else:
        layer.trainable = False  # Freeze layer lainnya

# Membuat input layer
inputs = Input(shape=(150, 150, 3))

# Menyusun model_VGG16_5
x = base_model(inputs)
x = GlobalAveragePooling2D()(x)
x = Dense(
    1024, 
    activation='relu', 
    kernel_regularizer=regularizers.l2(0.01)  # Menambahkan weight regularization
)(x)
x = Dropout(0.3)(x)
outputs = Dense(num_classes, activation='softmax')(x)  # Output layer

# Membuat model_VGG16_5
model_VGG16_5 = Model(inputs, outputs)

# Compile model_VGG16_5
model_VGG16_5.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Membuat checkpoint callback
checkpointVGG16_5 = ModelCheckpoint(
    'best_model_VGG16_5.h5', monitor='val_accuracy', verbose=1, save_best_only=True
)

# Early stopping minimal 10 epochs
class CustomEarlyStopping(EarlyStopping):
    def __init__(self, min_epochs=10, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.min_epochs = min_epochs

    def on_epoch_end(self, epoch, logs=None):
        # Cegah stop sebelum min_epochs terpenuhi
        if epoch + 1 < self.min_epochs:
            return
        super().on_epoch_end(epoch, logs)

# Custom EarlyStopping
custom_early_stopping = CustomEarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    min_epochs=10
)

# Training model_VGG16_5 dengan batch size 64
batch_size = 64
historyVGG16_5 = model_VGG16_5.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=30,
    validation_data=(x_validation, y_validation),
    callbacks=[checkpointVGG16_5, custom_early_stopping],
    verbose=1
)
# Out:
# Epoch 1/30
# 24/24 [==============================] - ETA: 0s - loss: 7.2900 - accuracy: 0.8219
# Epoch 1: val_accuracy improved from -inf to 0.92398, saving model to best_model_VGG16_5.h5
# 24/24 [==============================] - 148s 6s/step - loss: 7.2900 - accuracy: 0.8219 - val_loss: 6.5573 - val_accuracy: 0.9240
# Epoch 2/30
# 24/24 [==============================] - ETA: 0s - loss: 6.2820 - accuracy: 0.9432
# Epoch 2: val_accuracy improved from 0.92398 to 0.95906, saving model to best_model_VGG16_5.h5
# 24/24 [==============================] - 147s 6s/step - loss: 6.2820 - accuracy: 0.9432 - val_loss: 5.9747 - val_accuracy: 0.9591
# Epoch 3/30
# 24/24 [==============================] - ETA: 0s - loss: 5.7680 - accuracy: 0.9576
# Epoch 3: val_accuracy did not improve from 0.95906
# 24/24 [==============================] - 146s 6s/step - loss: 5.7680 - accuracy: 0.9576 - val_loss: 5.5090 - val_accuracy: 0.9532
# Epoch 4/30
# 24/24 [==============================] - ETA: 0s - loss: 5.2939 - accuracy: 0.9635
# Epoch 4: val_accuracy improved from 0.95906 to 0.96491, saving model to best_model_VGG16_5.h5
# 24/24 [==============================] - 146s 6s/step - loss: 5.2939 - accuracy: 0.9635 - val_loss: 5.0771 - val_accuracy: 0.9649
# Epoch 5/30
# 24/24 [==============================] - ETA: 0s - loss: 4.8580 - accuracy: 0.9720
# Epoch 5: val_accuracy improved from 0.96491 to 0.97076, saving model to best_model_VGG16_5.h5
# 24/24 [==============================] - 146s 6s/step - loss: 4.8580 - accuracy: 0.9720 - val_loss: 4.6972 - val_accuracy: 0.9708
# Epoch 6/30
# 24/24 [==============================] - ETA: 0s - loss: 4.4643 - accuracy: 0.9811
# Epoch 6: val_accuracy did not improve from 0.97076
# 24/24 [==============================] - 146s 6s/step - loss: 4.4643 - accuracy: 0.9811 - val_loss: 4.3370 - val_accuracy: 0.9708
# Epoch 7/30
# 24/24 [==============================] - ETA: 0s - loss: 4.1017 - accuracy: 0.9811
# Epoch 7: val_accuracy did not improve from 0.97076
# 24/24 [==============================] - 146s 6s/step - loss: 4.1017 - accuracy: 0.9811 - val_loss: 4.0161 - val_accuracy: 0.9708
# Epoch 8/30
# 24/24 [==============================] - ETA: 0s - loss: 3.7856 - accuracy: 0.9811
# Epoch 8: val_accuracy did not improve from 0.97076
# 24/24 [==============================] - 147s 6s/step - loss: 3.7856 - accuracy: 0.9811 - val_loss: 3.7694 - val_accuracy: 0.9532
# Epoch 9/30
# 24/24 [==============================] - ETA: 0s - loss: 3.4612 - accuracy: 0.9961
# Epoch 9: val_accuracy did not improve from 0.97076
# 24/24 [==============================] - 148s 6s/step - loss: 3.4612 - accuracy: 0.9961 - val_loss: 3.4847 - val_accuracy: 0.9591
# Epoch 10/30
# 24/24 [==============================] - ETA: 0s - loss: 3.2108 - accuracy: 0.9870
# Epoch 10: val_accuracy improved from 0.97076 to 0.97661, saving model to best_model_VGG16_5.h5
# 24/24 [==============================] - 148s 6s/step - loss: 3.2108 - accuracy: 0.9870 - val_loss: 3.1780 - val_accuracy: 0.9766
# Epoch 11/30
# 24/24 [==============================] - ETA: 0s - loss: 2.9773 - accuracy: 0.9837
# Epoch 11: val_accuracy did not improve from 0.97661
# 24/24 [==============================] - 148s 6s/step - loss: 2.9773 - accuracy: 0.9837 - val_loss: 2.9660 - val_accuracy: 0.9532
# Epoch 12/30
# 24/24 [==============================] - ETA: 0s - loss: 2.7497 - accuracy: 0.9811
# Epoch 12: val_accuracy did not improve from 0.97661
# 24/24 [==============================] - 147s 6s/step - loss: 2.7497 - accuracy: 0.9811 - val_loss: 2.6627 - val_accuracy: 0.9591
# Epoch 13/30
# 24/24 [==============================] - ETA: 0s - loss: 2.5341 - accuracy: 0.9876
# Epoch 13: val_accuracy did not improve from 0.97661
# 24/24 [==============================] - 148s 6s/step - loss: 2.5341 - accuracy: 0.9876 - val_loss: 2.4831 - val_accuracy: 0.9649
# Epoch 14/30
# 24/24 [==============================] - ETA: 0s - loss: 2.3162 - accuracy: 0.9980
# Epoch 14: val_accuracy did not improve from 0.97661
# 24/24 [==============================] - 147s 6s/step - loss: 2.3162 - accuracy: 0.9980 - val_loss: 2.6561 - val_accuracy: 0.9708
# Epoch 15/30
# 24/24 [==============================] - ETA: 0s - loss: 2.2107 - accuracy: 0.9752
# Epoch 15: val_accuracy did not improve from 0.97661
# 24/24 [==============================] - 158s 7s/step - loss: 2.2107 - accuracy: 0.9752 - val_loss: 2.1860 - val_accuracy: 0.9708
# Epoch 16/30
# 24/24 [==============================] - ETA: 0s - loss: 2.0226 - accuracy: 0.9830
# Epoch 16: val_accuracy did not improve from 0.97661
# 24/24 [==============================] - 161s 7s/step - loss: 2.0226 - accuracy: 0.9830 - val_loss: 2.0212 - val_accuracy: 0.9708
# Epoch 17/30
# 24/24 [==============================] - ETA: 0s - loss: 1.8484 - accuracy: 0.9980
# Epoch 17: val_accuracy did not improve from 0.97661
# 24/24 [==============================] - 169s 7s/step - loss: 1.8484 - accuracy: 0.9980 - val_loss: 1.9503 - val_accuracy: 0.9708
# Epoch 18/30
# 24/24 [==============================] - ETA: 0s - loss: 1.7205 - accuracy: 0.9954
# Epoch 18: val_accuracy did not improve from 0.97661
# 24/24 [==============================] - 208s 9s/step - loss: 1.7205 - accuracy: 0.9954 - val_loss: 1.7932 - val_accuracy: 0.9649
# Epoch 19/30
# 24/24 [==============================] - ETA: 0s - loss: 1.5991 - accuracy: 0.9987
# Epoch 19: val_accuracy did not improve from 0.97661
# 24/24 [==============================] - 177s 7s/step - loss: 1.5991 - accuracy: 0.9987 - val_loss: 1.6878 - val_accuracy: 0.9591
# Epoch 20/30
# 24/24 [==============================] - ETA: 0s - loss: 1.4864 - accuracy: 1.0000
# Epoch 20: val_accuracy did not improve from 0.97661
# 24/24 [==============================] - 178s 7s/step - loss: 1.4864 - accuracy: 1.0000 - val_loss: 1.6365 - val_accuracy: 0.9591
# Epoch 21/30
# 24/24 [==============================] - ETA: 0s - loss: 1.3872 - accuracy: 1.0000
# Epoch 21: val_accuracy did not improve from 0.97661
# 24/24 [==============================] - 188s 8s/step - loss: 1.3872 - accuracy: 1.0000 - val_loss: 1.5661 - val_accuracy: 0.9591
# Epoch 22/30
# 24/24 [==============================] - ETA: 0s - loss: 1.2977 - accuracy: 1.0000
# Epoch 22: val_accuracy did not improve from 0.97661
# 24/24 [==============================] - 206s 9s/step - loss: 1.2977 - accuracy: 1.0000 - val_loss: 1.4919 - val_accuracy: 0.9649
# Epoch 23/30
# 24/24 [==============================] - ETA: 0s - loss: 1.2162 - accuracy: 1.0000
# Epoch 23: val_accuracy did not improve from 0.97661
# 24/24 [==============================] - 192s 8s/step - loss: 1.2162 - accuracy: 1.0000 - val_loss: 1.4217 - val_accuracy: 0.9649
# Epoch 24/30
# 24/24 [==============================] - ETA: 0s - loss: 1.1419 - accuracy: 1.0000
# Epoch 24: val_accuracy did not improve from 0.97661
# 24/24 [==============================] - 185s 8s/step - loss: 1.1419 - accuracy: 1.0000 - val_loss: 1.3560 - val_accuracy: 0.9649
# Epoch 25/30
# 24/24 [==============================] - ETA: 0s - loss: 1.0740 - accuracy: 1.0000
# Epoch 25: val_accuracy did not improve from 0.97661
# 24/24 [==============================] - 197s 8s/step - loss: 1.0740 - accuracy: 1.0000 - val_loss: 1.2993 - val_accuracy: 0.9649
# Epoch 26/30
# 24/24 [==============================] - ETA: 0s - loss: 1.0120 - accuracy: 1.0000
# Epoch 26: val_accuracy did not improve from 0.97661
# 24/24 [==============================] - 230s 10s/step - loss: 1.0120 - accuracy: 1.0000 - val_loss: 1.2629 - val_accuracy: 0.9649
# Epoch 27/30
# 24/24 [==============================] - ETA: 0s - loss: 0.9552 - accuracy: 1.0000
# Epoch 27: val_accuracy did not improve from 0.97661
# 24/24 [==============================] - 206s 9s/step - loss: 0.9552 - accuracy: 1.0000 - val_loss: 1.2400 - val_accuracy: 0.9649
# Epoch 28/30
# 24/24 [==============================] - ETA: 0s - loss: 0.9033 - accuracy: 1.0000
# Epoch 28: val_accuracy did not improve from 0.97661
# 24/24 [==============================] - 189s 8s/step - loss: 0.9033 - accuracy: 1.0000 - val_loss: 1.2125 - val_accuracy: 0.9649
# Epoch 29/30
# 24/24 [==============================] - ETA: 0s - loss: 0.8557 - accuracy: 1.0000
# Epoch 29: val_accuracy did not improve from 0.97661
# 24/24 [==============================] - 179s 7s/step - loss: 0.8557 - accuracy: 1.0000 - val_loss: 1.1734 - val_accuracy: 0.9649
# Epoch 30/30
# 24/24 [==============================] - ETA: 0s - loss: 0.8120 - accuracy: 1.0000
# Epoch 30: val_accuracy did not improve from 0.97661
# 24/24 [==============================] - 188s 8s/step - loss: 0.8120 - accuracy: 1.0000 - val_loss: 1.1380 - val_accuracy: 0.9649

# %%
# Plot loss & akurasi
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

# Plot training & validation akurasi
ax1.plot(historyVGG16_5.history['accuracy'])
ax1.plot(historyVGG16_5.history['val_accuracy'])
ax1.set_title('Model Accuracy')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
ax2.plot(historyVGG16_5.history['loss'])
ax2.plot(historyVGG16_5.history['val_loss'])
ax2.set_title('Model Loss')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %%
# Evaluasi akurasi dan loss pada set validation
loss, accuracy = model_VGG16_5.evaluate(x_validation, y_validation)
print(f'validation accuracy: {accuracy*100:.3f}%')
print(f'validation loss: {loss:.4f}')

# Generate classification report
y_pred = model_VGG16_5.predict(x_validation)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_validation, axis=1)

# Membuat classification_report
class_report_VGG16_5 = classification_report(y_true, y_pred_classes, target_names=categories)
print('Classification Report Model CNN + VGG16 5:')
print(class_report_VGG16_5)
# Out:
# 6/6 [==============================] - 11s 2s/step - loss: 1.1380 - accuracy: 0.9649
# validation accuracy: 96.491%
# validation loss: 1.1380
# 6/6 [==============================] - 11s 2s/step
# Classification Report Model CNN + VGG16 5:
#               precision    recall  f1-score   support
#
#       Opened       0.98      0.95      0.97        87
#       Closed       0.95      0.98      0.96        84
#
#     accuracy                           0.96       171
#    macro avg       0.96      0.97      0.96       171
# weighted avg       0.97      0.96      0.96       171

# %%
# Plot confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred_classes)
print("Confusion Matrix:")
print(conf_matrix)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Greens', xticklabels=categories, yticklabels=categories)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Confusion Matrix:
# [[83  4]
#  [ 2 82]]

# %% [markdown]
# ### **Predict the New Data with Model VGG16 5**

# %%
# Load model_predict_5 .h5
model_predict_5 = tf.keras.models.load_model('best_model_VGG16_5.h5')

# directory yang mengandung Image test
test_dir = './drownisess/TestSet/TestSet'

categories = ['Opened', 'Closed']

X_samples = []
Y_samples = []

def preprocess_image(image_path):
    img = Image.open(image_path)
    img = img.resize((150, 150))  
    img_array = np.array(img)
    return img_array


for category in categories:
    folder_path = os.path.join(test_dir, category)
    image_files = os.listdir(folder_path)
    random.shuffle(image_files)
    selected_images = image_files[:5]

    for image_file in selected_images:
        image_path = os.path.join(folder_path, image_file)
        img_array = preprocess_image(image_path)
        X_samples.append(img_array)
        if category == 'Opened':
            Y_samples.append(0)
        else:
            Y_samples.append(1)

X_samples = np.array(X_samples)
Y_samples = np.array(Y_samples)

num_samples = 10
num_cols = 5
num_rows = num_samples // num_cols

plt.figure(figsize=(15, 5))
for i in range(num_samples):
    current_image = X_samples[i]
    actual_label = Y_samples[i]

    batch_prediction = model_predict_5.predict(np.expand_dims(current_image, axis=0))
    predicted_label = np.argmax(batch_prediction)

    disease_labels = ['Opened', 'Closed']

    predicted_class = disease_labels[predicted_label]

    actual_class = disease_labels[actual_label]

    plt.subplot(num_rows, num_cols, i + 1)
    plt.imshow(current_image)
    plt.axis('off')
    plt.title("Actual: {}\nPredicted: {}".format(actual_class, predicted_class), fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 396ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 116ms/step

# %% [markdown]
# ## **Model 6 CNN + VGG16 [No Trainable layer - Regularization Yes - Batch Size 64]**

# %% [markdown]
# Model keenam adalah model CNN dengan memakai model VGG16 dengan menambah 1 dropout 0.3 lalu menginisialisasi Checkpoint Callback untuk menyimpan model dengan validation akurasi terbaik, lalu parameter yang akan dibandingkan adalah model CNN yang disuntikan model transfer learning VGG16 tanpa melakukan training layer VGG16, memakai regularization dan batch size = 64

# %%
# Load base model dengan VGG16
base_model = tf.keras.applications.VGG16(
    include_top=False,
    weights='imagenet',
    input_tensor=None,
    input_shape = (150, 150, 3),
    classes=2,
)

# Freeze model transfer learning dengan trainable = False (dinonaktifkan tariningnya)
base_model.trainable = False

# Menyusun model_VGG16_6
inputs = Input(shape=(150, 150, 3))
x = base_model(inputs, training=False)
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation = 'relu', kernel_regularizer=regularizers.l2(0.01))(x)
x = Dropout(0.3)(x)
# Output layer dengan softmax activation untuk multi-class classification dengan jumlah neuron sama dengan jumlah kelas
outputs = Dense(num_classes, activation = 'softmax')(x)

# Membuat model_VGG16_6
model_VGG16_6 = Model(inputs, outputs)

# Compile model_VGG16_6
model_VGG16_6.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Membuat checkpoint callback
checkpointVGG16_6 = ModelCheckpoint(
    'best_model_VGG16_6.h5', monitor='val_accuracy', verbose=1, save_best_only=True
)

# Early stopping minimal 10 epochs
class CustomEarlyStopping(EarlyStopping):
    def __init__(self, min_epochs=10, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.min_epochs = min_epochs

    def on_epoch_end(self, epoch, logs=None):
        # Cegah stop sebelum min_epochs terpenuhi
        if epoch + 1 < self.min_epochs:
            return
        super().on_epoch_end(epoch, logs)

# Custom EarlyStopping
custom_early_stopping = CustomEarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    min_epochs=10
)

# Training model_VGG16_6 dengan batch size 64
batch_size = 64
historyVGG16_6 = model_VGG16_6.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=30,
    validation_data=(x_validation, y_validation),
    callbacks=[checkpointVGG16_6, custom_early_stopping],
    verbose=1
)
# Out:
# Epoch 1/30
# 24/24 [==============================] - ETA: 0s - loss: 8.7782 - accuracy: 0.6432
# Epoch 1: val_accuracy improved from -inf to 0.88889, saving model to best_model_VGG16_6.h5
# 24/24 [==============================] - 112s 5s/step - loss: 8.7782 - accuracy: 0.6432 - val_loss: 6.8513 - val_accuracy: 0.8889
# Epoch 2/30
# 24/24 [==============================] - ETA: 0s - loss: 7.0255 - accuracy: 0.8526
# Epoch 2: val_accuracy did not improve from 0.88889
# 24/24 [==============================] - 117s 5s/step - loss: 7.0255 - accuracy: 0.8526 - val_loss: 6.5141 - val_accuracy: 0.8889
# Epoch 3/30
# 24/24 [==============================] - ETA: 0s - loss: 6.5479 - accuracy: 0.8780
# Epoch 3: val_accuracy improved from 0.88889 to 0.90058, saving model to best_model_VGG16_6.h5
# 24/24 [==============================] - 114s 5s/step - loss: 6.5479 - accuracy: 0.8780 - val_loss: 6.1081 - val_accuracy: 0.9006
# Epoch 4/30
# 24/24 [==============================] - ETA: 0s - loss: 6.1924 - accuracy: 0.8832
# Epoch 4: val_accuracy improved from 0.90058 to 0.91813, saving model to best_model_VGG16_6.h5
# 24/24 [==============================] - 112s 5s/step - loss: 6.1924 - accuracy: 0.8832 - val_loss: 5.8228 - val_accuracy: 0.9181
# Epoch 5/30
# 24/24 [==============================] - ETA: 0s - loss: 5.7717 - accuracy: 0.8950
# Epoch 5: val_accuracy improved from 0.91813 to 0.92982, saving model to best_model_VGG16_6.h5
# 24/24 [==============================] - 115s 5s/step - loss: 5.7717 - accuracy: 0.8950 - val_loss: 5.4205 - val_accuracy: 0.9298
# Epoch 6/30
# 24/24 [==============================] - ETA: 0s - loss: 5.5377 - accuracy: 0.8950
# Epoch 6: val_accuracy improved from 0.92982 to 0.93567, saving model to best_model_VGG16_6.h5
# 24/24 [==============================] - 106s 4s/step - loss: 5.5377 - accuracy: 0.8950 - val_loss: 5.1147 - val_accuracy: 0.9357
# Epoch 7/30
# 24/24 [==============================] - ETA: 0s - loss: 5.1558 - accuracy: 0.9008
# Epoch 7: val_accuracy improved from 0.93567 to 0.95322, saving model to best_model_VGG16_6.h5
# 24/24 [==============================] - 102s 4s/step - loss: 5.1558 - accuracy: 0.9008 - val_loss: 4.8349 - val_accuracy: 0.9532
# Epoch 8/30
# 24/24 [==============================] - ETA: 0s - loss: 4.9713 - accuracy: 0.9119
# Epoch 8: val_accuracy did not improve from 0.95322
# 24/24 [==============================] - 102s 4s/step - loss: 4.9713 - accuracy: 0.9119 - val_loss: 4.5758 - val_accuracy: 0.9298
# Epoch 9/30
# 24/24 [==============================] - ETA: 0s - loss: 4.6446 - accuracy: 0.9159
# Epoch 9: val_accuracy did not improve from 0.95322
# 24/24 [==============================] - 105s 4s/step - loss: 4.6446 - accuracy: 0.9159 - val_loss: 4.3449 - val_accuracy: 0.9474
# Epoch 10/30
# 24/24 [==============================] - ETA: 0s - loss: 4.4387 - accuracy: 0.9145
# Epoch 10: val_accuracy did not improve from 0.95322
# 24/24 [==============================] - 102s 4s/step - loss: 4.4387 - accuracy: 0.9145 - val_loss: 4.1393 - val_accuracy: 0.9240
# Epoch 11/30
# 24/24 [==============================] - ETA: 0s - loss: 4.2321 - accuracy: 0.9145
# Epoch 11: val_accuracy did not improve from 0.95322
# 24/24 [==============================] - 99s 4s/step - loss: 4.2321 - accuracy: 0.9145 - val_loss: 3.9519 - val_accuracy: 0.9415
# Epoch 12/30
# 24/24 [==============================] - ETA: 0s - loss: 3.9939 - accuracy: 0.9295
# Epoch 12: val_accuracy improved from 0.95322 to 0.95906, saving model to best_model_VGG16_6.h5
# 24/24 [==============================] - 100s 4s/step - loss: 3.9939 - accuracy: 0.9295 - val_loss: 3.7391 - val_accuracy: 0.9591
# Epoch 13/30
# 24/24 [==============================] - ETA: 0s - loss: 3.8303 - accuracy: 0.9269
# Epoch 13: val_accuracy did not improve from 0.95906
# 24/24 [==============================] - 100s 4s/step - loss: 3.8303 - accuracy: 0.9269 - val_loss: 3.6091 - val_accuracy: 0.9415
# Epoch 14/30
# 24/24 [==============================] - ETA: 0s - loss: 3.6356 - accuracy: 0.9256
# Epoch 14: val_accuracy did not improve from 0.95906
# 24/24 [==============================] - 100s 4s/step - loss: 3.6356 - accuracy: 0.9256 - val_loss: 3.4186 - val_accuracy: 0.9357
# Epoch 15/30
# 24/24 [==============================] - ETA: 0s - loss: 3.4970 - accuracy: 0.9250
# Epoch 15: val_accuracy did not improve from 0.95906
# 24/24 [==============================] - 100s 4s/step - loss: 3.4970 - accuracy: 0.9250 - val_loss: 3.2842 - val_accuracy: 0.9415
# Epoch 16/30
# 24/24 [==============================] - ETA: 0s - loss: 3.2932 - accuracy: 0.9387
# Epoch 16: val_accuracy did not improve from 0.95906
# 24/24 [==============================] - 93s 4s/step - loss: 3.2932 - accuracy: 0.9387 - val_loss: 3.1877 - val_accuracy: 0.9357
# Epoch 17/30
# 24/24 [==============================] - ETA: 0s - loss: 3.1726 - accuracy: 0.9341
# Epoch 17: val_accuracy did not improve from 0.95906
# 24/24 [==============================] - 93s 4s/step - loss: 3.1726 - accuracy: 0.9341 - val_loss: 3.0293 - val_accuracy: 0.9474
# Epoch 18/30
# 24/24 [==============================] - ETA: 0s - loss: 3.0707 - accuracy: 0.9295
# Epoch 18: val_accuracy did not improve from 0.95906
# 24/24 [==============================] - 93s 4s/step - loss: 3.0707 - accuracy: 0.9295 - val_loss: 2.9291 - val_accuracy: 0.9474
# Epoch 19/30
# 24/24 [==============================] - ETA: 0s - loss: 2.9321 - accuracy: 0.9380
# Epoch 19: val_accuracy did not improve from 0.95906
# 24/24 [==============================] - 93s 4s/step - loss: 2.9321 - accuracy: 0.9380 - val_loss: 2.8276 - val_accuracy: 0.9415
# Epoch 20/30
# 24/24 [==============================] - ETA: 0s - loss: 2.8245 - accuracy: 0.9432
# Epoch 20: val_accuracy did not improve from 0.95906
# 24/24 [==============================] - 95s 4s/step - loss: 2.8245 - accuracy: 0.9432 - val_loss: 2.6997 - val_accuracy: 0.9591
# Epoch 21/30
# 24/24 [==============================] - ETA: 0s - loss: 2.7295 - accuracy: 0.9348
# Epoch 21: val_accuracy did not improve from 0.95906
# 24/24 [==============================] - 87s 4s/step - loss: 2.7295 - accuracy: 0.9348 - val_loss: 2.6270 - val_accuracy: 0.9415
# Epoch 22/30
# 24/24 [==============================] - ETA: 0s - loss: 2.6111 - accuracy: 0.9406
# Epoch 22: val_accuracy did not improve from 0.95906
# 24/24 [==============================] - 87s 4s/step - loss: 2.6111 - accuracy: 0.9406 - val_loss: 2.5192 - val_accuracy: 0.9474
# Epoch 23/30
# 24/24 [==============================] - ETA: 0s - loss: 2.5106 - accuracy: 0.9472
# Epoch 23: val_accuracy did not improve from 0.95906
# 24/24 [==============================] - 87s 4s/step - loss: 2.5106 - accuracy: 0.9472 - val_loss: 2.4438 - val_accuracy: 0.9474
# Epoch 24/30
# 24/24 [==============================] - ETA: 0s - loss: 2.4528 - accuracy: 0.9341
# Epoch 24: val_accuracy did not improve from 0.95906
# 24/24 [==============================] - 87s 4s/step - loss: 2.4528 - accuracy: 0.9341 - val_loss: 2.3851 - val_accuracy: 0.9532
# Epoch 25/30
# 24/24 [==============================] - ETA: 0s - loss: 2.3577 - accuracy: 0.9530
# Epoch 25: val_accuracy did not improve from 0.95906
# 24/24 [==============================] - 90s 4s/step - loss: 2.3577 - accuracy: 0.9530 - val_loss: 2.2933 - val_accuracy: 0.9532
# Epoch 26/30
# 24/24 [==============================] - ETA: 0s - loss: 2.2583 - accuracy: 0.9550
# Epoch 26: val_accuracy did not improve from 0.95906
# 24/24 [==============================] - 87s 4s/step - loss: 2.2583 - accuracy: 0.9550 - val_loss: 2.2360 - val_accuracy: 0.9532
# Epoch 27/30
# 24/24 [==============================] - ETA: 0s - loss: 2.2286 - accuracy: 0.9406
# Epoch 27: val_accuracy did not improve from 0.95906
# 24/24 [==============================] - 86s 4s/step - loss: 2.2286 - accuracy: 0.9406 - val_loss: 2.2372 - val_accuracy: 0.9240
# Epoch 28/30
# 24/24 [==============================] - ETA: 0s - loss: 2.1596 - accuracy: 0.9465
# Epoch 28: val_accuracy did not improve from 0.95906
# 24/24 [==============================] - 87s 4s/step - loss: 2.1596 - accuracy: 0.9465 - val_loss: 2.1438 - val_accuracy: 0.9415
# Epoch 29/30
# 24/24 [==============================] - ETA: 0s - loss: 2.1131 - accuracy: 0.9465
# Epoch 29: val_accuracy did not improve from 0.95906
# 24/24 [==============================] - 86s 4s/step - loss: 2.1131 - accuracy: 0.9465 - val_loss: 2.0490 - val_accuracy: 0.9474
# Epoch 30/30
# 24/24 [==============================] - ETA: 0s - loss: 2.0146 - accuracy: 0.9576
# Epoch 30: val_accuracy did not improve from 0.95906
# 24/24 [==============================] - 86s 4s/step - loss: 2.0146 - accuracy: 0.9576 - val_loss: 2.0179 - val_accuracy: 0.9415

# %%
# Plot loss & akurasi
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

# Plot training & validation akurasi
ax1.plot(historyVGG16_6.history['accuracy'])
ax1.plot(historyVGG16_6.history['val_accuracy'])
ax1.set_title('Model Accuracy')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
ax2.plot(historyVGG16_6.history['loss'])
ax2.plot(historyVGG16_6.history['val_loss'])
ax2.set_title('Model Loss')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %%
# Evaluasi akurasi dan loss pada set validation
loss, accuracy = model_VGG16_6.evaluate(x_validation, y_validation)
print(f'validation accuracy: {accuracy*100:.3f}%')
print(f'validation loss: {loss:.4f}')

# Generate classification report
y_pred = model_VGG16_6.predict(x_validation)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_validation, axis=1)

# Membuat classification_report
class_report_VGG16_6 = classification_report(y_true, y_pred_classes, target_names=categories)
print('Classification Report Model CNN + VGG1619 6:')
print(class_report_VGG16_6)
# Out:
# 6/6 [==============================] - 11s 2s/step - loss: 2.0179 - accuracy: 0.9415
# validation accuracy: 94.152%
# validation loss: 2.0179
# 6/6 [==============================] - 9s 1s/step
# Classification Report Model CNN + VGG1619 6:
#               precision    recall  f1-score   support
#
#       Opened       0.98      0.91      0.94        87
#       Closed       0.91      0.98      0.94        84
#
#     accuracy                           0.94       171
#    macro avg       0.94      0.94      0.94       171
# weighted avg       0.94      0.94      0.94       171

# %%
# Plot confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred_classes)
print("Confusion Matrix:")
print(conf_matrix)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Greens', xticklabels=categories, yticklabels=categories)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Confusion Matrix:
# [[79  8]
#  [ 2 82]]

# %% [markdown]
# ### **Predict the New Data with Model VGG16 6**

# %%
# Load model_predict_6 .h5
model_predict_6 = tf.keras.models.load_model('best_model_VGG16_6.h5')

# directory yang mengandung Image test
test_dir = './drownisess/TestSet/TestSet'

categories = ['Opened', 'Closed']

X_samples = []
Y_samples = []

def preprocess_image(image_path):
    img = Image.open(image_path)
    img = img.resize((150, 150))  
    img_array = np.array(img)
    return img_array


for category in categories:
    folder_path = os.path.join(test_dir, category)
    image_files = os.listdir(folder_path)
    random.shuffle(image_files)
    selected_images = image_files[:5]

    for image_file in selected_images:
        image_path = os.path.join(folder_path, image_file)
        img_array = preprocess_image(image_path)
        X_samples.append(img_array)
        if category == 'Opened':
            Y_samples.append(0)
        else:
            Y_samples.append(1)

X_samples = np.array(X_samples)
Y_samples = np.array(Y_samples)

num_samples = 10
num_cols = 5
num_rows = num_samples // num_cols

plt.figure(figsize=(15, 5))
for i in range(num_samples):
    current_image = X_samples[i]
    actual_label = Y_samples[i]

    batch_prediction = model_predict_6.predict(np.expand_dims(current_image, axis=0))
    predicted_label = np.argmax(batch_prediction)

    disease_labels = ['Opened', 'Closed']

    predicted_class = disease_labels[predicted_label]

    actual_class = disease_labels[actual_label]

    plt.subplot(num_rows, num_cols, i + 1)
    plt.imshow(current_image)
    plt.axis('off')
    plt.title("Actual: {}\nPredicted: {}".format(actual_class, predicted_class), fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 205ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 78ms/step

# %% [markdown]
# ## **Model 7 CNN + VGG16 [Trainable layer - Regularization No - Batch Size 64]**

# %% [markdown]
# Model ketujuh adalah model CNN dengan memakai model VGG16 dengan menambah 1 dropout 0.3 lalu menginisialisasi Checkpoint Callback untuk menyimpan model dengan validation akurasi terbaik, lalu parameter yang akan dibandingkan adalah model CNN yang disuntikan model transfer learning VGG16 dengan melakukan training layer VGG16, tanpa regularization dan batch size = 64

# %%
# Load base model dengan VGG16
base_model = tf.keras.applications.VGG16(
    include_top=False,
    weights='imagenet',
    input_tensor=None,
    input_shape = (150, 150, 3),
    classes=2,
)

# Membuka layer convolutional dan pooling tertentu untuk dilatih
conv_count, pool_count = 0, 0
for layer in reversed(base_model.layers):  # Iterasi dari belakang
    if isinstance(layer, tf.keras.layers.Conv2D) and conv_count < 5:
        layer.trainable = True
        conv_count += 1
    elif isinstance(layer, tf.keras.layers.MaxPooling2D) and pool_count < 3:
        layer.trainable = True
        pool_count += 1
    else:
        layer.trainable = False  # Freeze layer lainnya

# Membuat input layer
inputs = Input(shape=(150, 150, 3))

# Menyusun model_VGG16_7
x = base_model(inputs)
x = GlobalAveragePooling2D()(x)
x = Dense(
    1024, 
    activation='relu')(x)
x = Dropout(0.3)(x)
outputs = Dense(num_classes, activation='softmax')(x)  # Output layer

# Membuat model_VGG16_7
model_VGG16_7 = Model(inputs, outputs)

# Compile model_VGG16_7
model_VGG16_7.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Membuat checkpoint callback
checkpointVGG16_7 = ModelCheckpoint(
    'best_model_VGG16_7.h5', monitor='val_accuracy', verbose=1, save_best_only=True
)

# Early stopping minimal 10 epochs
class CustomEarlyStopping(EarlyStopping):
    def __init__(self, min_epochs=10, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.min_epochs = min_epochs

    def on_epoch_end(self, epoch, logs=None):
        # Cegah stop sebelum min_epochs terpenuhi
        if epoch + 1 < self.min_epochs:
            return
        super().on_epoch_end(epoch, logs)

# Custom EarlyStopping
custom_early_stopping = CustomEarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    min_epochs=10
)

# Training model_VGG16_7 dengan batch size 64
batch_size = 64
historyVGG16_7 = model_VGG16_7.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=30,
    validation_data=(x_validation, y_validation),
    callbacks=[checkpointVGG16_7, custom_early_stopping],
    verbose=1
)
# Out:
# Epoch 1/30
# 24/24 [==============================] - ETA: 0s - loss: 0.6438 - accuracy: 0.8050
# Epoch 1: val_accuracy improved from -inf to 0.95322, saving model to best_model_VGG16_7.h5
# 24/24 [==============================] - 151s 6s/step - loss: 0.6438 - accuracy: 0.8050 - val_loss: 0.1426 - val_accuracy: 0.9532
# Epoch 2/30
# 24/24 [==============================] - ETA: 0s - loss: 0.1685 - accuracy: 0.9446
# Epoch 2: val_accuracy improved from 0.95322 to 0.95906, saving model to best_model_VGG16_7.h5
# 24/24 [==============================] - 149s 6s/step - loss: 0.1685 - accuracy: 0.9446 - val_loss: 0.1272 - val_accuracy: 0.9591
# Epoch 3/30
# 24/24 [==============================] - ETA: 0s - loss: 0.1134 - accuracy: 0.9583
# Epoch 3: val_accuracy improved from 0.95906 to 0.98246, saving model to best_model_VGG16_7.h5
# 24/24 [==============================] - 148s 6s/step - loss: 0.1134 - accuracy: 0.9583 - val_loss: 0.0937 - val_accuracy: 0.9825
# Epoch 4/30
# 24/24 [==============================] - ETA: 0s - loss: 0.0989 - accuracy: 0.9609
# Epoch 4: val_accuracy did not improve from 0.98246
# 24/24 [==============================] - 148s 6s/step - loss: 0.0989 - accuracy: 0.9609 - val_loss: 0.1509 - val_accuracy: 0.9649
# Epoch 5/30
# 24/24 [==============================] - ETA: 0s - loss: 0.0741 - accuracy: 0.9739
# Epoch 5: val_accuracy did not improve from 0.98246
# 24/24 [==============================] - 152s 6s/step - loss: 0.0741 - accuracy: 0.9739 - val_loss: 0.1049 - val_accuracy: 0.9708
# Epoch 6/30
# 24/24 [==============================] - ETA: 0s - loss: 0.1197 - accuracy: 0.9667
# Epoch 6: val_accuracy did not improve from 0.98246
# 24/24 [==============================] - 151s 6s/step - loss: 0.1197 - accuracy: 0.9667 - val_loss: 0.1051 - val_accuracy: 0.9649
# Epoch 7/30
# 24/24 [==============================] - ETA: 0s - loss: 0.0801 - accuracy: 0.9739
# Epoch 7: val_accuracy did not improve from 0.98246
# 24/24 [==============================] - 152s 6s/step - loss: 0.0801 - accuracy: 0.9739 - val_loss: 0.0888 - val_accuracy: 0.9708
# Epoch 8/30
# 24/24 [==============================] - ETA: 0s - loss: 0.0607 - accuracy: 0.9746
# Epoch 8: val_accuracy did not improve from 0.98246
# 24/24 [==============================] - 163s 7s/step - loss: 0.0607 - accuracy: 0.9746 - val_loss: 0.0943 - val_accuracy: 0.9708
# Epoch 9/30
# 24/24 [==============================] - ETA: 0s - loss: 0.0234 - accuracy: 0.9928
# Epoch 9: val_accuracy did not improve from 0.98246
# 24/24 [==============================] - 160s 7s/step - loss: 0.0234 - accuracy: 0.9928 - val_loss: 0.1576 - val_accuracy: 0.9708
# Epoch 10/30
# 24/24 [==============================] - ETA: 0s - loss: 0.0369 - accuracy: 0.9876
# Epoch 10: val_accuracy did not improve from 0.98246
# 24/24 [==============================] - 159s 7s/step - loss: 0.0369 - accuracy: 0.9876 - val_loss: 0.1018 - val_accuracy: 0.9708
# Epoch 11/30
# 24/24 [==============================] - ETA: 0s - loss: 0.0270 - accuracy: 0.9902
# Epoch 11: val_accuracy did not improve from 0.98246
# 24/24 [==============================] - 161s 7s/step - loss: 0.0270 - accuracy: 0.9902 - val_loss: 0.1607 - val_accuracy: 0.9649
# Epoch 12/30
# 24/24 [==============================] - ETA: 0s - loss: 0.0184 - accuracy: 0.9941
# Epoch 12: val_accuracy did not improve from 0.98246
# 24/24 [==============================] - 149s 6s/step - loss: 0.0184 - accuracy: 0.9941 - val_loss: 0.1575 - val_accuracy: 0.9708
# Epoch 13/30
# 24/24 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 0.9974
# Epoch 13: val_accuracy did not improve from 0.98246
# 24/24 [==============================] - 148s 6s/step - loss: 0.0080 - accuracy: 0.9974 - val_loss: 0.2429 - val_accuracy: 0.9766
# Epoch 14/30
# 24/24 [==============================] - ETA: 0s - loss: 0.0335 - accuracy: 0.9896
# Epoch 14: val_accuracy did not improve from 0.98246
# 24/24 [==============================] - 147s 6s/step - loss: 0.0335 - accuracy: 0.9896 - val_loss: 0.1906 - val_accuracy: 0.9766
# Epoch 15/30
# 24/24 [==============================] - ETA: 0s - loss: 0.0209 - accuracy: 0.9935
# Epoch 15: val_accuracy did not improve from 0.98246
# 24/24 [==============================] - 147s 6s/step - loss: 0.0209 - accuracy: 0.9935 - val_loss: 0.2974 - val_accuracy: 0.9649
# Epoch 16/30
# 24/24 [==============================] - ETA: 0s - loss: 0.0162 - accuracy: 0.9935
# Epoch 16: val_accuracy did not improve from 0.98246
# 24/24 [==============================] - 148s 6s/step - loss: 0.0162 - accuracy: 0.9935 - val_loss: 0.3328 - val_accuracy: 0.9766
# Epoch 17/30
# 24/24 [==============================] - ETA: 0s - loss: 0.0124 - accuracy: 0.9954
# Epoch 17: val_accuracy did not improve from 0.98246
# 24/24 [==============================] - 149s 6s/step - loss: 0.0124 - accuracy: 0.9954 - val_loss: 0.1631 - val_accuracy: 0.9766
# Epoch 18/30
# 24/24 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9993
# Epoch 18: val_accuracy did not improve from 0.98246
# 24/24 [==============================] - 150s 6s/step - loss: 0.0020 - accuracy: 0.9993 - val_loss: 0.1983 - val_accuracy: 0.9766
# Epoch 19/30
# 24/24 [==============================] - ETA: 0s - loss: 4.1011e-04 - accuracy: 1.0000
# Epoch 19: val_accuracy did not improve from 0.98246
# 24/24 [==============================] - 150s 6s/step - loss: 4.1011e-04 - accuracy: 1.0000 - val_loss: 0.2860 - val_accuracy: 0.9708
# Epoch 20/30
# 24/24 [==============================] - ETA: 0s - loss: 2.2570e-04 - accuracy: 1.0000
# Epoch 20: val_accuracy did not improve from 0.98246
# 24/24 [==============================] - 151s 6s/step - loss: 2.2570e-04 - accuracy: 1.0000 - val_loss: 0.2407 - val_accuracy: 0.9708

# %%
# Plot loss & akurasi
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

# Plot training & validation akurasi
ax1.plot(historyVGG16_7.history['accuracy'])
ax1.plot(historyVGG16_7.history['val_accuracy'])
ax1.set_title('Model Accuracy')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
ax2.plot(historyVGG16_7.history['loss'])
ax2.plot(historyVGG16_7.history['val_loss'])
ax2.set_title('Model Loss')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %%
# Evaluasi akurasi dan loss pada set validation
loss, accuracy = model_VGG16_7.evaluate(x_validation, y_validation)
print(f'validation accuracy: {accuracy*100:.3f}%')
print(f'validation loss: {loss:.4f}')

# Generate classification report
y_pred = model_VGG16_7.predict(x_validation)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_validation, axis=1)

# Membuat classification_report
class_report_VGG16_7 = classification_report(y_true, y_pred_classes, target_names=categories)
print('Classification Report Model CNN + VGG16 7:')
print(class_report_VGG16_7)
# Out:
# 6/6 [==============================] - 9s 1s/step - loss: 0.1018 - accuracy: 0.9708
# validation accuracy: 97.076%
# validation loss: 0.1018
# 6/6 [==============================] - 9s 2s/step
# Classification Report Model CNN + VGG16 7:
#               precision    recall  f1-score   support
#
#       Opened       0.98      0.97      0.97        87
#       Closed       0.96      0.98      0.97        84
#
#     accuracy                           0.97       171
#    macro avg       0.97      0.97      0.97       171
# weighted avg       0.97      0.97      0.97       171

# %%
# Plot confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred_classes)
print("Confusion Matrix:")
print(conf_matrix)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Greens', xticklabels=categories, yticklabels=categories)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Confusion Matrix:
# [[84  3]
#  [ 2 82]]

# %% [markdown]
# ### **Predict the New Data with Model VGG16 7**

# %%
# Load model_predict_7 .h5
model_predict_7 = tf.keras.models.load_model('best_model_VGG16_7.h5')

# directory yang mengandung Image test
test_dir = './drownisess/TestSet/TestSet'

categories = ['Opened', 'Closed']

X_samples = []
Y_samples = []

def preprocess_image(image_path):
    img = Image.open(image_path)
    img = img.resize((150, 150))  
    img_array = np.array(img)
    return img_array


for category in categories:
    folder_path = os.path.join(test_dir, category)
    image_files = os.listdir(folder_path)
    random.shuffle(image_files)
    selected_images = image_files[:5]

    for image_file in selected_images:
        image_path = os.path.join(folder_path, image_file)
        img_array = preprocess_image(image_path)
        X_samples.append(img_array)
        if category == 'Opened':
            Y_samples.append(0)
        else:
            Y_samples.append(1)

X_samples = np.array(X_samples)
Y_samples = np.array(Y_samples)

num_samples = 10
num_cols = 5
num_rows = num_samples // num_cols

plt.figure(figsize=(15, 5))
for i in range(num_samples):
    current_image = X_samples[i]
    actual_label = Y_samples[i]

    batch_prediction = model_predict_7.predict(np.expand_dims(current_image, axis=0))
    predicted_label = np.argmax(batch_prediction)

    disease_labels = ['Opened', 'Closed']

    predicted_class = disease_labels[predicted_label]

    actual_class = disease_labels[actual_label]

    plt.subplot(num_rows, num_cols, i + 1)
    plt.imshow(current_image)
    plt.axis('off')
    plt.title("Actual: {}\nPredicted: {}".format(actual_class, predicted_class), fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 80ms/step

# %% [markdown]
# ## **Model 8 CNN + VGG16 [No Trainable layer - Regularization No - Batch Size 64]**

# %% [markdown]
# Model kedepalapn adalah model CNN dengan memakai model VGG16 dengan menambah 1 dropout 0.3 lalu menginisialisasi Checkpoint Callback untuk menyimpan model dengan validation akurasi terbaik, lalu parameter yang akan dibandingkan adalah model CNN yang disuntikan model transfer learning VGG16 tanpa melakukan training layer VGG16, tanpa regularization dan batch size = 64

# %%
# Load base model dengan VGG16
base_model = tf.keras.applications.VGG16(
    include_top=False,
    weights='imagenet',
    input_tensor=None,
    input_shape = (150, 150, 3),
    classes=2,
)

# Freeze model transfer learning dengan trainable = False (dinonaktifkan tariningnya)
base_model.trainable = False

# Menyusun model_VGG16_8
inputs = Input(shape=(150, 150, 3))
x = base_model(inputs, training=False)
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation = 'relu')(x)
x = Dropout(0.3)(x)
# Output layer dengan softmax activation untuk multi-class classification dengan jumlah neuron sama dengan jumlah kelas
outputs = Dense(num_classes, activation = 'softmax')(x)

# Membuat model_VGG16_8
model_VGG16_8 = Model(inputs, outputs)

# Compile model_VGG16_8
model_VGG16_8.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Membuat checkpoint callback
checkpointVGG16_8 = ModelCheckpoint(
    'best_model_VGG16_8.h5', monitor='val_accuracy', verbose=1, save_best_only=True
)

# Early stopping minimal 10 epochs
class CustomEarlyStopping(EarlyStopping):
    def __init__(self, min_epochs=10, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.min_epochs = min_epochs

    def on_epoch_end(self, epoch, logs=None):
        # Cegah stop sebelum min_epochs terpenuhi
        if epoch + 1 < self.min_epochs:
            return
        super().on_epoch_end(epoch, logs)

# Custom EarlyStopping
custom_early_stopping = CustomEarlyStopping(
    monitor='val_loss',
    patience=10,
    restore_best_weights=True,
    min_epochs=10
)

# Training model_VGG16_8 dengan batch size 64
batch_size = 64
historyVGG16_8 = model_VGG16_8.fit(
    x_train,
    y_train,
    batch_size=batch_size,
    epochs=30,
    validation_data=(x_validation, y_validation),
    callbacks=[checkpointVGG16_8, custom_early_stopping],
    verbose=1
)
# Out:
# Epoch 1/30
# 24/24 [==============================] - ETA: 0s - loss: 1.2136 - accuracy: 0.7430
# Epoch 1: val_accuracy improved from -inf to 0.91813, saving model to best_model_VGG16_8.h5
# 24/24 [==============================] - 89s 4s/step - loss: 1.2136 - accuracy: 0.7430 - val_loss: 0.3732 - val_accuracy: 0.9181
# Epoch 2/30
# 24/24 [==============================] - ETA: 0s - loss: 0.6400 - accuracy: 0.8728
# Epoch 2: val_accuracy did not improve from 0.91813
# 24/24 [==============================] - 88s 4s/step - loss: 0.6400 - accuracy: 0.8728 - val_loss: 0.2936 - val_accuracy: 0.9181
# Epoch 3/30
# 24/24 [==============================] - ETA: 0s - loss: 0.5541 - accuracy: 0.8950
# Epoch 3: val_accuracy did not improve from 0.91813
# 24/24 [==============================] - 91s 4s/step - loss: 0.5541 - accuracy: 0.8950 - val_loss: 0.2798 - val_accuracy: 0.9181
# Epoch 4/30
# 24/24 [==============================] - ETA: 0s - loss: 0.4604 - accuracy: 0.9087
# Epoch 4: val_accuracy did not improve from 0.91813
# 24/24 [==============================] - 88s 4s/step - loss: 0.4604 - accuracy: 0.9087 - val_loss: 0.2416 - val_accuracy: 0.9181
# Epoch 5/30
# 24/24 [==============================] - ETA: 0s - loss: 0.4638 - accuracy: 0.9035
# Epoch 5: val_accuracy improved from 0.91813 to 0.92982, saving model to best_model_VGG16_8.h5
# 24/24 [==============================] - 89s 4s/step - loss: 0.4638 - accuracy: 0.9035 - val_loss: 0.2138 - val_accuracy: 0.9298
# Epoch 6/30
# 24/24 [==============================] - ETA: 0s - loss: 0.4707 - accuracy: 0.9035
# Epoch 6: val_accuracy did not improve from 0.92982
# 24/24 [==============================] - 88s 4s/step - loss: 0.4707 - accuracy: 0.9035 - val_loss: 0.2740 - val_accuracy: 0.9298
# Epoch 7/30
# 24/24 [==============================] - ETA: 0s - loss: 0.3209 - accuracy: 0.9204
# Epoch 7: val_accuracy improved from 0.92982 to 0.94152, saving model to best_model_VGG16_8.h5
# 24/24 [==============================] - 89s 4s/step - loss: 0.3209 - accuracy: 0.9204 - val_loss: 0.1751 - val_accuracy: 0.9415
# Epoch 8/30
# 24/24 [==============================] - ETA: 0s - loss: 0.3259 - accuracy: 0.9243
# Epoch 8: val_accuracy did not improve from 0.94152
# 24/24 [==============================] - 87s 4s/step - loss: 0.3259 - accuracy: 0.9243 - val_loss: 0.1988 - val_accuracy: 0.9357
# Epoch 9/30
# 24/24 [==============================] - ETA: 0s - loss: 0.3000 - accuracy: 0.9315
# Epoch 9: val_accuracy did not improve from 0.94152
# 24/24 [==============================] - 88s 4s/step - loss: 0.3000 - accuracy: 0.9315 - val_loss: 0.1668 - val_accuracy: 0.9298
# Epoch 10/30
# 24/24 [==============================] - ETA: 0s - loss: 0.3028 - accuracy: 0.9191
# Epoch 10: val_accuracy did not improve from 0.94152
# 24/24 [==============================] - 88s 4s/step - loss: 0.3028 - accuracy: 0.9191 - val_loss: 0.1762 - val_accuracy: 0.9298
# Epoch 11/30
# 24/24 [==============================] - ETA: 0s - loss: 0.2996 - accuracy: 0.9243
# Epoch 11: val_accuracy did not improve from 0.94152
# 24/24 [==============================] - 88s 4s/step - loss: 0.2996 - accuracy: 0.9243 - val_loss: 0.1485 - val_accuracy: 0.9415
# Epoch 12/30
# 24/24 [==============================] - ETA: 0s - loss: 0.2694 - accuracy: 0.9289
# Epoch 12: val_accuracy improved from 0.94152 to 0.94737, saving model to best_model_VGG16_8.h5
# 24/24 [==============================] - 88s 4s/step - loss: 0.2694 - accuracy: 0.9289 - val_loss: 0.1520 - val_accuracy: 0.9474
# Epoch 13/30
# 24/24 [==============================] - ETA: 0s - loss: 0.3061 - accuracy: 0.9282
# Epoch 13: val_accuracy did not improve from 0.94737
# 24/24 [==============================] - 88s 4s/step - loss: 0.3061 - accuracy: 0.9282 - val_loss: 0.2000 - val_accuracy: 0.9474
# Epoch 14/30
# 24/24 [==============================] - ETA: 0s - loss: 0.2588 - accuracy: 0.9322
# Epoch 14: val_accuracy did not improve from 0.94737
# 24/24 [==============================] - 88s 4s/step - loss: 0.2588 - accuracy: 0.9322 - val_loss: 0.2078 - val_accuracy: 0.9474
# Epoch 15/30
# 24/24 [==============================] - ETA: 0s - loss: 0.2326 - accuracy: 0.9406
# Epoch 15: val_accuracy did not improve from 0.94737
# 24/24 [==============================] - 89s 4s/step - loss: 0.2326 - accuracy: 0.9406 - val_loss: 0.1743 - val_accuracy: 0.9415
# Epoch 16/30
# 24/24 [==============================] - ETA: 0s - loss: 0.2173 - accuracy: 0.9374
# Epoch 16: val_accuracy did not improve from 0.94737
# 24/24 [==============================] - 88s 4s/step - loss: 0.2173 - accuracy: 0.9374 - val_loss: 0.1807 - val_accuracy: 0.9298
# Epoch 17/30
# 24/24 [==============================] - ETA: 0s - loss: 0.2075 - accuracy: 0.9465
# Epoch 17: val_accuracy did not improve from 0.94737
# 24/24 [==============================] - 88s 4s/step - loss: 0.2075 - accuracy: 0.9465 - val_loss: 0.1690 - val_accuracy: 0.9474
# Epoch 18/30
# 24/24 [==============================] - ETA: 0s - loss: 0.1687 - accuracy: 0.9472
# Epoch 18: val_accuracy did not improve from 0.94737
# 24/24 [==============================] - 88s 4s/step - loss: 0.1687 - accuracy: 0.9472 - val_loss: 0.2067 - val_accuracy: 0.9357
# Epoch 19/30
# 24/24 [==============================] - ETA: 0s - loss: 0.1874 - accuracy: 0.9530
# Epoch 19: val_accuracy did not improve from 0.94737
# 24/24 [==============================] - 88s 4s/step - loss: 0.1874 - accuracy: 0.9530 - val_loss: 0.1773 - val_accuracy: 0.9415
# Epoch 20/30
# 24/24 [==============================] - ETA: 0s - loss: 0.1665 - accuracy: 0.9517
# Epoch 20: val_accuracy did not improve from 0.94737
# 24/24 [==============================] - 88s 4s/step - loss: 0.1665 - accuracy: 0.9517 - val_loss: 0.1915 - val_accuracy: 0.9357
# Epoch 21/30
# 24/24 [==============================] - ETA: 0s - loss: 0.1375 - accuracy: 0.9556
# Epoch 21: val_accuracy did not improve from 0.94737
# 24/24 [==============================] - 88s 4s/step - loss: 0.1375 - accuracy: 0.9556 - val_loss: 0.1414 - val_accuracy: 0.9474
# Epoch 22/30
# 24/24 [==============================] - ETA: 0s - loss: 0.1407 - accuracy: 0.9465
# Epoch 22: val_accuracy did not improve from 0.94737
# 24/24 [==============================] - 88s 4s/step - loss: 0.1407 - accuracy: 0.9465 - val_loss: 0.1558 - val_accuracy: 0.9474
# Epoch 23/30
# 24/24 [==============================] - ETA: 0s - loss: 0.1388 - accuracy: 0.9602
# Epoch 23: val_accuracy did not improve from 0.94737
# 24/24 [==============================] - 88s 4s/step - loss: 0.1388 - accuracy: 0.9602 - val_loss: 0.1784 - val_accuracy: 0.9474
# Epoch 24/30
# 24/24 [==============================] - ETA: 0s - loss: 0.1468 - accuracy: 0.9511
# Epoch 24: val_accuracy did not improve from 0.94737
# 24/24 [==============================] - 88s 4s/step - loss: 0.1468 - accuracy: 0.9511 - val_loss: 0.1714 - val_accuracy: 0.9474
# Epoch 25/30
# 24/24 [==============================] - ETA: 0s - loss: 0.1202 - accuracy: 0.9602
# Epoch 25: val_accuracy did not improve from 0.94737
# 24/24 [==============================] - 92s 4s/step - loss: 0.1202 - accuracy: 0.9602 - val_loss: 0.1727 - val_accuracy: 0.9415
# Epoch 26/30
# 24/24 [==============================] - ETA: 0s - loss: 0.1244 - accuracy: 0.9589
# Epoch 26: val_accuracy improved from 0.94737 to 0.95322, saving model to best_model_VGG16_8.h5
# 24/24 [==============================] - 96s 4s/step - loss: 0.1244 - accuracy: 0.9589 - val_loss: 0.1773 - val_accuracy: 0.9532
# Epoch 27/30
# 24/24 [==============================] - ETA: 0s - loss: 0.1047 - accuracy: 0.9635
# Epoch 27: val_accuracy did not improve from 0.95322
# 24/24 [==============================] - 98s 4s/step - loss: 0.1047 - accuracy: 0.9635 - val_loss: 0.1481 - val_accuracy: 0.9532
# Epoch 28/30
# 24/24 [==============================] - ETA: 0s - loss: 0.0999 - accuracy: 0.9635
# Epoch 28: val_accuracy did not improve from 0.95322
# 24/24 [==============================] - 98s 4s/step - loss: 0.0999 - accuracy: 0.9635 - val_loss: 0.2381 - val_accuracy: 0.9298
# Epoch 29/30
# 24/24 [==============================] - ETA: 0s - loss: 0.1186 - accuracy: 0.9609
# Epoch 29: val_accuracy did not improve from 0.95322
# 24/24 [==============================] - 102s 4s/step - loss: 0.1186 - accuracy: 0.9609 - val_loss: 0.1553 - val_accuracy: 0.9474
# Epoch 30/30
# 24/24 [==============================] - ETA: 0s - loss: 0.1168 - accuracy: 0.9641
# Epoch 30: val_accuracy did not improve from 0.95322
# 24/24 [==============================] - 98s 4s/step - loss: 0.1168 - accuracy: 0.9641 - val_loss: 0.1833 - val_accuracy: 0.9474

# %%
# Plot loss & akurasi
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

# Plot training & validation akurasi
ax1.plot(historyVGG16_8.history['accuracy'])
ax1.plot(historyVGG16_8.history['val_accuracy'])
ax1.set_title('Model Accuracy')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend(['Train', 'Validation'], loc='upper left')

# Plot training & validation loss values
ax2.plot(historyVGG16_8.history['loss'])
ax2.plot(historyVGG16_8.history['val_loss'])
ax2.set_title('Model Loss')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend(['Train', 'Validation'], loc='upper left')

plt.tight_layout()
plt.show()

# %%
# Evaluasi akurasi dan loss pada set validation
loss, accuracy = model_VGG16_8.evaluate(x_validation, y_validation)
print(f'validation accuracy: {accuracy*100:.3f}%')
print(f'validation loss: {loss:.4f}')

# Generate classification report
y_pred = model_VGG16_8.predict(x_validation)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_validation, axis=1)

# Membuat classification_report
class_report_VGG16_8 = classification_report(y_true, y_pred_classes, target_names=categories)
print('Classification Report Model CNN + VGG16 8:')
print(class_report_VGG16_8)
# Out:
# 6/6 [==============================] - 9s 2s/step - loss: 0.1833 - accuracy: 0.9474
# validation accuracy: 94.737%
# validation loss: 0.1833
# 6/6 [==============================] - 9s 1s/step
# Classification Report Model CNN + VGG16 8:
#               precision    recall  f1-score   support
#
#       Opened       0.96      0.93      0.95        87
#       Closed       0.93      0.96      0.95        84
#
#     accuracy                           0.95       171
#    macro avg       0.95      0.95      0.95       171
# weighted avg       0.95      0.95      0.95       171

# %%
# Plot confusion matrix
conf_matrix = confusion_matrix(y_true, y_pred_classes)
print("Confusion Matrix:")
print(conf_matrix)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Greens', xticklabels=categories, yticklabels=categories)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Confusion Matrix:
# [[81  6]
#  [ 3 81]]

# %% [markdown]
# ### **Predict the New Data with Model VGG16 8**

# %%
# Load model_predict_8 .h5
model_predict_8 = tf.keras.models.load_model('best_model_VGG16_8.h5')

# directory yang mengandung Image test
test_dir = './drownisess/TestSet/TestSet'

categories = ['Opened', 'Closed']

X_samples = []
Y_samples = []

def preprocess_image(image_path):
    img = Image.open(image_path)
    img = img.resize((150, 150))  
    img_array = np.array(img)
    return img_array


for category in categories:
    folder_path = os.path.join(test_dir, category)
    image_files = os.listdir(folder_path)
    random.shuffle(image_files)
    selected_images = image_files[:5]

    for image_file in selected_images:
        image_path = os.path.join(folder_path, image_file)
        img_array = preprocess_image(image_path)
        X_samples.append(img_array)
        if category == 'Opened':
            Y_samples.append(0)
        else:
            Y_samples.append(1)

X_samples = np.array(X_samples)
Y_samples = np.array(Y_samples)

num_samples = 10
num_cols = 5
num_rows = num_samples // num_cols

plt.figure(figsize=(15, 5))
for i in range(num_samples):
    current_image = X_samples[i]
    actual_label = Y_samples[i]

    batch_prediction = model_predict_8.predict(np.expand_dims(current_image, axis=0))
    predicted_label = np.argmax(batch_prediction)

    disease_labels = ['Opened', 'Closed']

    predicted_class = disease_labels[predicted_label]

    actual_class = disease_labels[actual_label]

    plt.subplot(num_rows, num_cols, i + 1)
    plt.imshow(current_image)
    plt.axis('off')
    plt.title("Actual: {}\nPredicted: {}".format(actual_class, predicted_class), fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 224ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 79ms/step

# %% [markdown]
# ## **Model Evaluation**

# %%
import time

# List model file paths
model_paths = [
    'best_model_VGG16_1.h5',
    'best_model_VGG16_2.h5',
    'best_model_VGG16_3.h5',
    'best_model_VGG16_4.h5',
    'best_model_VGG16_5.h5',
    'best_model_VGG16_6.h5',
    'best_model_VGG16_7.h5',
    'best_model_VGG16_8.h5'
]

# Placeholder untuk nama kategori
categories = ['Opened', 'Closed']  # Sesuaikan dengan kategori Anda

# Loop untuk mengevaluasi setiap model
for model_path in model_paths:
    print(f"\n# Evaluasi model: {model_path}")
    
    # Load model
    model = tf.keras.models.load_model(model_path)
    
    # Start timer untuk runtime
    start_time = time.time()
    
    # Evaluasi model pada validation set
    validation_loss, validation_accuracy = model.evaluate(x_validation, y_validation, verbose=1)
    
    # Prediksi untuk classification report
    y_pred = model.predict(x_validation, verbose=1)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_true = np.argmax(y_validation, axis=1)
    
    # Hitung runtime
    runtime = time.time() - start_time
    
    # Classification report
    class_report = classification_report(y_true, y_pred_classes, target_names=categories)

    # confusion matrix
    conf_matrix = confusion_matrix(y_true, y_pred_classes)
    
    # Tampilkan hasil evaluasi
    print(f"\nRuntime: {runtime:.1f} s")
    print(f"Validation Accuracy: {validation_accuracy * 100:.3f}%")
    print(f"Validation Loss: {validation_loss:.4f}")
    print("Classification Report:")
    print(class_report)
    print("Confusion Matrix:")
    print(conf_matrix)
# Out:
# # Evaluasi model: best_model_VGG16_1.h5
# 6/6 [==============================] - 12s 1s/step - loss: 0.9851 - accuracy: 0.9766
# 6/6 [==============================] - 10s 2s/step
#
# Runtime: 21.6 s
# Validation Accuracy: 97.661%
# Validation Loss: 0.9851
# Classification Report:
#               precision    recall  f1-score   support
#
#       Opened       0.98      0.98      0.98        87
#       Closed       0.98      0.98      0.98        84
#
#     accuracy                           0.98       171
#    macro avg       0.98      0.98      0.98       171
# weighted avg       0.98      0.98      0.98       171
#
# Confusion Matrix:
# [[85  2]
#  [ 2 82]]
#
# # Evaluasi model: best_model_VGG16_2.h5
# 6/6 [==============================] - 10s 2s/step - loss: 2.0065 - accuracy: 0.9591
# 6/6 [==============================] - 10s 2s/step
#
# Runtime: 19.4 s
# Validation Accuracy: 95.906%
# Validation Loss: 2.0065
# Classification Report:
#               precision    recall  f1-score   support
#
#       Opened       0.98      0.94      0.96        87
#       Closed       0.94      0.98      0.96        84
#
#     accuracy                           0.96       171
#    macro avg       0.96      0.96      0.96       171
# weighted avg       0.96      0.96      0.96       171
#
# Confusion Matrix:
# [[82  5]
#  [ 2 82]]
#
# # Evaluasi model: best_model_VGG16_3.h5
# 6/6 [==============================] - 10s 2s/step - loss: 0.1203 - accuracy: 0.9825
# 6/6 [==============================] - 10s 2s/step
#
# Runtime: 20.0 s
# Validation Accuracy: 98.246%
# Validation Loss: 0.1203
# Classification Report:
#               precision    recall  f1-score   support
#
#       Opened       0.99      0.98      0.98        87
#       Closed       0.98      0.99      0.98        84
#
#     accuracy                           0.98       171
#    macro avg       0.98      0.98      0.98       171
# weighted avg       0.98      0.98      0.98       171
#
# Confusion Matrix:
# [[85  2]
#  [ 1 83]]
#
# # Evaluasi model: best_model_VGG16_4.h5
# 6/6 [==============================] - 10s 2s/step - loss: 0.2062 - accuracy: 0.9591
# 6/6 [==============================] - 10s 2s/step
#
# Runtime: 19.5 s
# Validation Accuracy: 95.906%
# Validation Loss: 0.2062
# Classification Report:
#               precision    recall  f1-score   support
#
#       Opened       0.98      0.94      0.96        87
#       Closed       0.94      0.98      0.96        84
#
#     accuracy                           0.96       171
#    macro avg       0.96      0.96      0.96       171
# weighted avg       0.96      0.96      0.96       171
#
# Confusion Matrix:
# [[82  5]
#  [ 2 82]]
#
# # Evaluasi model: best_model_VGG16_5.h5
# 6/6 [==============================] - 10s 2s/step - loss: 3.1780 - accuracy: 0.9766
# 6/6 [==============================] - 10s 2s/step
#
# Runtime: 20.2 s
# Validation Accuracy: 97.661%
# Validation Loss: 3.1780
# Classification Report:
#               precision    recall  f1-score   support
#
#       Opened       1.00      0.95      0.98        87
#       Closed       0.95      1.00      0.98        84
#
#     accuracy                           0.98       171
#    macro avg       0.98      0.98      0.98       171
# weighted avg       0.98      0.98      0.98       171
#
# Confusion Matrix:
# [[83  4]
#  [ 0 84]]
#
# # Evaluasi model: best_model_VGG16_6.h5
# 6/6 [==============================] - 10s 2s/step - loss: 3.7391 - accuracy: 0.9591
# 6/6 [==============================] - 9s 1s/step
#
# Runtime: 19.3 s
# Validation Accuracy: 95.906%
# Validation Loss: 3.7391
# Classification Report:
#               precision    recall  f1-score   support
#
#       Opened       0.98      0.94      0.96        87
#       Closed       0.94      0.98      0.96        84
#
#     accuracy                           0.96       171
#    macro avg       0.96      0.96      0.96       171
# weighted avg       0.96      0.96      0.96       171
#
# Confusion Matrix:
# [[82  5]
#  [ 2 82]]
#
# # Evaluasi model: best_model_VGG16_7.h5
# 6/6 [==============================] - 11s 2s/step - loss: 0.0937 - accuracy: 0.9825
# 6/6 [==============================] - 10s 2s/step
#
# Runtime: 20.5 s
# Validation Accuracy: 98.246%
# Validation Loss: 0.0937
# Classification Report:
#               precision    recall  f1-score   support
#
#       Opened       1.00      0.97      0.98        87
#       Closed       0.97      1.00      0.98        84
#
#     accuracy                           0.98       171
#    macro avg       0.98      0.98      0.98       171
# weighted avg       0.98      0.98      0.98       171
#
# Confusion Matrix:
# [[84  3]
#  [ 0 84]]
#
# # Evaluasi model: best_model_VGG16_8.h5
# 6/6 [==============================] - 9s 1s/step - loss: 0.1773 - accuracy: 0.9532
# 6/6 [==============================] - 9s 2s/step
#
# Runtime: 18.7 s
# Validation Accuracy: 95.322%
# Validation Loss: 0.1773
# Classification Report:
#               precision    recall  f1-score   support
#
#       Opened       0.96      0.94      0.95        87
#       Closed       0.94      0.96      0.95        84
#
#     accuracy                           0.95       171
#    macro avg       0.95      0.95      0.95       171
# weighted avg       0.95      0.95      0.95       171
#
# Confusion Matrix:
# [[82  5]
#  [ 3 81]]

# %% [markdown]
# ## **Kesimpulan**

# %% [markdown]
# Pada project Computer Vision ini menggunakan algoritma Convolutional Neural Network yang disuntikan model transfer learning VGG16 dengan membandingkan jika sebuah Model CNN dilakukan trainable pada beberapa layer transfer learning, diberi atau tidak diberikan parameter regularizer dan perbedaan batch size. Kedelapan model CNN ini dapat dibandingkan untuk melihat model mana yang menghasilkan akurasi paling baik, runtime terendah, dan loss terendah. Berikut adalah hasil perbadingan akurasi dari keempat model:
#
# 1. Model CNN VGG16 1 dengan Trainable layer, dengan Regularizers, dan batch Size 32 ===> `Loss: 0.9851 ; Validation Acc: 97.6% ; F1-Score: 98% (21.6 s)`
# 2. Model CNN VGG16 2 tanpa Trainable layer, dengan Regularizers dan batch Size 32 =====> `Loss: 2.0065 ; Validation Acc: 95.9% ; F1-Score: 96% (19.4 s)`
# 3. Model CNN VGG16 3 dengan Trainable layer, tanpa Regularizers, dan batch Size 32 ====> `Loss: 0.1203 ; Validation Acc: 98.2% ; F1-Score: 98% (20.0 s`)
# 4. Model CNN VGG16 4 tanpa Trainable layer, tanpa Regularizers, dan batch Size 32 =====> `Loss: 0.2062 ; Validation Acc: 95.9% ; F1-Score: 96% (19.5 s)`
# 5. Model CNN VGG16 5 dengan Trainable layer, dengan Regularizers, dan batch Size 64 ===> `Loss: 3.1780 ; Validation Acc: 97.6% ; F1-Score: 98% (20.2 s)`
# 6. Model CNN VGG16 6 tanpa Trainable layer, dengan Regularizers, dan batch Size 64 ====> `Loss: 3.7391 ; Validation Acc: 95.9% ; F1-Score: 96% (19.3 s)`
# 7. **Model CNN VGG16 7 dengan Trainable layer, tanpa Regularizers, dan batch Size 64 ====> `Loss: 0.0937 ; Validation Acc: 98.2% ; F1-Score: 98% (20.5 s`)**
# 8. Model CNN VGG16 8 tanpa Trainable layer, tanpa Regularizers, dan batch Size 64 =====> `Loss: 0.1773 ; Validation Acc: 95.3% ; F1-Score: 95% (18.7 s)`
#
# Seluruh model tidak memiliki overvitting maupun underfitting yang ditunjukan dari plot visualisasi loss dan akurasi data training dan validation. Oleh karena itu Model **CNN VGG16 7 dengan Trainable layer, tanpa Regularizers, dan batch Size 64** menjadi model paling baik untuk dataset model kantuk ini.
#
# Untuk pemodelan lebih lanjut, data pada folder TrainingSet dapat ditambahkan data dari ImprovementSet untuk memperbanyak data dan bisa menambah akurasi yang dihasilkan nantinya.
